# %% [markdown]
# # AEON

# %% [markdown]
# В этой лекции мы более подробно поработаем с библиотекой aeon
#
# Aeon — это совместимый с scikit-learn набор инструментов для работы с временными рядами (TSML). Он организован в
# модули для различных задач обучения: классификация, регрессия, кластеризация, прогнозирование, обнаружение аномалий, сегментация и поиск по сходству.
#
# Aeon - хорошо документированная библиотека, имеет большое количество блокнотов, доступных в [документации](https://www.aeon-toolkit.org/en/stable/). Эта работа составлена на основе блокнотов, представленных в руководстве.
#
# Будем использовать для примера наборы данных ЭЭГ. Все используемые типы данных представляют собой трехмерные массивы (3D numpy arrays).

# %% [markdown]
# # Структуры данных и наборы данных
#
# *aeon* предполагает, что один временной ряд представляет собой двумерный массив формы `(n_channels, n_timepoints)`.
#
# Классификаторы и регрессоры принимают входные коллекции временных рядов (и наследуют от BaseCollectionEstimator).
#
# Если все серии имеют одинаковую длину, лучше всего работает с трехмерной фигурой `(n_cases, n_channels, n_timepoints)`.
#
# Серии разной длины хранятся в списках 2D numpy, но примеры, которые мы собираемся использовать, будут иметь одинаковую длину.
#
# В этом уроке в качестве рабочего примера будут использоваться данные ЭЭГ.
#
# Классификационный набор данных состоит из показаний ЭЭГ, снятых у испытуемого в состоянии покоя или при выполнении заданной задачи (поднятие рук). Полную информацию об этих данных можно найти в [блокноте](https://github.com/aeon-toolkit/aeon-neuro/blob/main/examples/data_loading.ipynb).
#
# *aeon* поставляется с некоторыми стандартными наборами данных UCR и UEA, и их все можно загрузить непосредственно с [timeseriesclassification.com](https://timeseriesclassification.com).

# %% [markdown]
# # Содержание
#
# * [Меры расстояний](#distance-tsc)
# * [Distance-based univariate Time Series Classification (TSC)](#classification)
# * [Distance-based  Time Series Extrinsic Regression](#regres)
# * [Подходы, основанные на свертках](#conv)
# * [Feature based classification and regression](#feature)
# * [Deep Learning подходы](#deep)
# * [Упражнения](#tasks)

# %% [markdown]
# ## Меры расстояний  <a id="distance-tsc"></a>
# Подходы, основанные на сходстве, были одним из первых предложений по классификации и регрессии временных рядов. Более того, эти типы методов также распространены для выполнения других задач временных рядов, таких как кластеризация или обнаружение аномалий и других.
#
# В первой части этой тетради представлены расстояния, реализованные в эоне, начиная с самого простого — евклидова расстояния. Затем он представляет расстояние динамического искажения времени (DTW), его варианты, такие как Amerced DTW (ADTW) или Shape DTW (ShapeDTW), а также некоторые другие альтернативные расстояния, такие как Move-Split-Merge (MSM).
#
# Во второй части этого блокнота мы демонстрируем использование этих расстояний в сочетании с классификатором KNearestNeighbours из scikit-learn, а также более подходящую реализацию KNearestNeighbours для временных рядов, включенных в aeon. Аналогичным образом также представлены подходы к работе с наборами данных TSER с использованием дистанционных подходов.
#
# Документация aeon содержит записные книжки по   [растоянию](https://www.aeon-toolkit.org/en/stable/examples/distances/distances.html) and [классификации на основе дистанции](https://www.aeon-toolkit.org/en/stable/examples/classification/distance_based.html) и искользования `aeon` расстояних с [`scikit-learn`](https://www.aeon-toolkit.org/en/stable/examples/distances/sklearn_distances.html).

# %%
# %pip install aeon[all_extras]
# %mkdir -p dataset
# Out:
# Requirement already satisfied: aeon[all_extras] in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (1.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2.3.0,>=1.21.0 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from aeon[all_extras]) (1.26.4)
# Requirement already satisfied: scikit-learn<1.7.0,>=1.0.0 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from aeon[all_extras]) (1.5.2)
# Requirement already satisfied: scipy<1.16.0,>=1.9.0 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from aeon[all_extras]) (1.12.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from aeon[all_extras]) (4.15.0)
# Requirement already satisfied: deprecated>=1.2.13 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from aeon[all_extras]) (1.3.1)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from aeon[all_extras]) (2.0.3)
# Requirement already satisfied: numba<0.62.0,>=0.55 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from aeon[all_extras]) (0.60.0)
# Requirement already satisfied: packaging>=20.0 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from aeon[all_extras]) (26.0)
# Requirement already satisfied: wrapt<3,>=1.10 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from deprecated>=1.2.13->aeon[all_extras]) (2.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from numba<0.62.0,>=0.55->aeon[all_extras]) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from pandas<2.3.0,>=2.0.0->aeon[all_extras]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from pandas<2.3.0,>=2.0.0->aeon[all_extras]) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.1 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from pandas<2.3.0,>=2.0.0->aeon[all_extras]) (2026.1)
# Requirement already satisfied: six>=1.5 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=2.0.0->aeon[all_extras]) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from scikit-learn<1.7.0,>=1.0.0->aeon[all_extras]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in f:\education\1course\2trim\regressionanalysis\.venv\lib\site-packages (from scikit-learn<1.7.0,>=1.0.0->aeon[all_extras]) (3.6.0)
# WARNING: aeon 1.1.0 does not provide the extra 'all_extras'
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'f:\Education\1course\2trim\RegressionAnalysis\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# �������� ��� 䠩� -p 㦥 �������.
# �訡�� �� �६� ��ࠡ�⪨: -p.
# �������� ��� 䠩� dataset 㦥 �������.
# �訡�� �� �६� ��ࠡ�⪨: dataset.

# %% [markdown]
# Чтобы использовать следующие команды, нужно убедиться, что wget установлен в вашей системе
# Скачать нужную версию wget можно с официального сайта  https://eternallybored.org/misc/wget/
# После скачивания - положить wget.exe сюда C:\Windows\System32
#
# Проблема windows еще и в том, что в powershell установлены allias  для iwr, curl, wget. При попытке к запустить эти команды будет запускаться виндовская Invoke-WebRequest .
# Поэтому или запускать с указанием расширения (например, wget.exe), или измненить алиас. Сделать это можно следующим образом.
#
# 1. Запускаем powershell или cmd.
#
# 2. Смотрим, что привязано к комманде wget:
# Get-Alias -Name wget
#
# 3. Если видите ответ типа "Alias           wget -> Invoke-WebRequest", то удаляем алиас:
# Remove-Item -Path Alias:\wget
#
# 4. Проверяем командой 2. Должно выдать ошибку.
#
# 5. Устанавливаем новый алиас
# New-Alias wget wget.exe
#
# Все, спокойно пользуемся привычным wget - ом.

# %%
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TEST.ts -P dataset/
# Out:
# "wget" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.
# "wget" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.
# "wget" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.
# "wget" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.
# "wget" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.
# "wget" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.
# "wget" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.
# "wget" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.

# %%
# это опционально, если хотите видеть все ворнинги - не запускайте эту ячейку

import warnings

warnings.filterwarnings("ignore")

# %%
import os
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"
import tensorflow as tf
tf.__version__
# Out:
# '2.20.0'

# %%
from aeon.datasets import load_from_ts_file

# Загрузите одномерный набор данных TSC как двумерный массив NumPy

X_train_utsc, y_train_utsc = load_from_ts_file("./dataset/KDD_UTSC_TRAIN.ts", return_type="numpy2D")
X_test_utsc, y_test_utsc = load_from_ts_file("./dataset/KDD_UTSC_TEST.ts", return_type="numpy2D")

print("Single channel EEG TSC problem train shape:", X_train_utsc.shape)
print("Single channel EEG TSC problem test shape:", X_test_utsc.shape)
# Out:
# Single channel EEG TSC problem train shape: (40, 100)
# Single channel EEG TSC problem test shape: (40, 100)

# %%
# Загрузите многомерный набор данных в виде трехмерного массива numpy

X_train_mtsc, y_train_mtsc = load_from_ts_file("./dataset/KDD_MTSC_TRAIN.ts")
X_test_mtsc, y_test_mtsc = load_from_ts_file("./dataset/KDD_MTSC_TEST.ts")

print("Four channel EEG TSC problem train shape:", X_train_mtsc.shape)
print("Four channel EEG TSC problem test shape:", X_test_mtsc.shape)
# Out:
# Four channel EEG TSC problem train shape: (40, 4, 100)
# Four channel EEG TSC problem test shape: (40, 4, 100)

# %%
# Загрузите одномерный набор данных TSER как двумерный массив numpy
X_train_utser, y_train_utser = load_from_ts_file("./dataset/KDD_UTSER_TRAIN.ts", return_type="numpy2D")
X_test_utser, y_test_utser = load_from_ts_file("./dataset/KDD_UTSER_TEST.ts", return_type="numpy2D")

print("Single channel EEG TSER problem train shape:", X_train_utsc.shape)
print("Single channel EEG TSER problem test shape:", X_test_utsc.shape)
# Out:
# Single channel EEG TSER problem train shape: (40, 100)
# Single channel EEG TSER problem test shape: (40, 100)

# %%
# Загрузите многомерный набор данных TSER в виде трехмерного массива numpy
X_train_mtser, y_train_mtser = load_from_ts_file("./dataset/KDD_MTSER_TRAIN.ts")
X_test_mtser, y_test_mtser = load_from_ts_file("./dataset/KDD_MTSER_TEST.ts")

print("Four channel EEG TSER problem train shape:", X_train_mtser.shape)
print("Four channel EEG TSER problem test shape:", X_test_mtser.shape)
# Out:
# Four channel EEG TSER problem train shape: (72, 4, 100)
# Four channel EEG TSER problem test shape: (72, 4, 100)

# %% [markdown]
# Для наших примеров измерения расстояния давайте определим два разных случайных одномерных временных ряда (a и b) длиной m=10 и построим их график.

# %%
from aeon.testing.data_generation import make_example_1d_numpy
import seaborn as sns
import matplotlib.pyplot as plt

a = make_example_1d_numpy(n_timepoints=10, random_state=0)
b = make_example_1d_numpy(n_timepoints=10, random_state=1)

sns.lineplot(data=a, label=r"$\mathbf{a}$")
sns.lineplot(data=b, label=r"$\mathbf{b}$")

plt.show()

# %% [markdown]
# #### Euclidean Distance (direct alignment)

# %%
# Считаем по формуле вручную

import numpy as np

ED = np.sqrt(np.sum(np.power(a-b,2)))

print(f"The Euclidean distance between a and b is {ED}")
# Out:
# The Euclidean distance between a and b is 1.236743116180222

# %%
# Используем aeon

from aeon.distances import euclidean_distance

print(
    f"The Euclidean distance computed in aeon between a and b is",
    f"{euclidean_distance(a, b)}"
)
# Out:
# The Euclidean distance computed in aeon between a and b is 1.236743116180222

# %%
# Постройте расстояния временных рядов поточечно, следуя по пути.
def plot_time_series_distances(a, b, cost_matrix, path):
    sns.lineplot(data=a, label=r"$\mathbf{a}$")
    sns.lineplot(data=b, label=r"$\mathbf{b}$")

    # соединить точки на пути
    for i in range(len(path)):
        plt.plot(
            [path[i][0], path[i][1]],
            [a[path[i][0]], b[path[i][1]]],
            'k--',
            alpha=0.2
        )
        plt.text(
            (path[i][0]+path[i][1])/2,
            (a[path[i][0]]+b[path[i][1]])/2,
            f"{cost_matrix[path[i][0], path[i][1]]:.2f}"
        )

    return plt

# Вычислите квадрат матрицы расстояний между a и b.
def squared_pointwise_distance(a, b):
    n_timesteps = len(a)
    distances_matrix = np.zeros((n_timesteps, n_timesteps))

    for i in range(n_timesteps):
        for j in range(n_timesteps):
            distances_matrix[i, j] = (a[i]-b[j])**2

    return distances_matrix


cost_matrix = squared_pointwise_distance(a,b)
path = [(i, i) for i in range(len(a))]

ax = plot_time_series_distances(a, b, cost_matrix, path)

plt.show()

# %% [markdown]
# Евклидово расстояние также можно определить как квадратный корень из суммы квадратов разностей значений на диагонали всех возможных расстояний между элементами в обоих временных рядах.
#
# Прежде всего, мы вычисляем матрицу расстояний, которая содержит расстояния для всех элементов обоих временных рядов:

# %%
from aeon.visualisation.distances._pairwise_distance_matrix import plot_pairwise_distance_matrix

# Compute the squared pointwise distances between a and b
distance_matrix = squared_pointwise_distance(a, b)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(distance_matrix, a, b, path)
plt.show()

# %% [markdown]
# #### Гибкое расстояние: динамическое искажение времени (DTW)
#  DTW допускает выравнивание по временным шагам, т. е. не обязательно выравнивать временные шаги, а только первый и последний временные шаги.
#
# В этом первом примере мы позволяем DTW иметь последовательные выравнивания, продвигающиеся не более чем на один временной шаг в каждой серии.

# %%
from aeon.distances import dtw_distance

print(
    f"The DTW distance computed in aeon between a and b is",
    f"{dtw_distance(a, b, window=0.1)}"
)
# Out:
# The DTW distance computed in aeon between a and b is 1.1985498275436108

# %%
from aeon.distances import dtw_alignment_path, dtw_cost_matrix

path, _ = dtw_alignment_path(a, b, window=0.1)
cost_matrix = dtw_cost_matrix(a, b, window=0.1)

sns.lineplot(data=a, label=r"$\mathbf{a}$")
sns.lineplot(data=b, label=r"$\mathbf{b}$")

# join the points in the path
for i in range(len(path)):
    plt.plot([path[i][0], path[i][1]], [a[path[i][0]], b[path[i][1]]], 'k--', alpha=0.2)
    plt.text(
        (path[i][0]+path[i][1])/2,
        (a[path[i][0]]+b[path[i][1]])/2,
        f"{cost_matrix[path[i][0], path[i][1]]:.2f}"
    )

plt.show()

# %% [markdown]
# Сравните графики DTW и декартового расстояния. Какие выводы?

# %% [markdown]
# Как можно заметить, теперь расстояния не вычисляются для одних и тех же моментов времени. Они
# рассчитываются с учетом коллиндантных моментов времени.
#
# В этом случае расстояние — это путь с минимальной стоимостью, который удовлетворяет вышеупомянутым условиям.
#
# Ограничения:
#
# (Обратите внимание, что для удобства чтения пути начальная позиция должна быть последней,
# в данном случае (9,9), и мы перемещаем ближайшую точку времени. Например, из (9,9) мы
# может перейти в: A) (8, 9) со стоимостью 1,32, B) (8, 8) со стоимостью 1,32 или C) (9, 8)
# со стоимостью 1,17. Последнее - правильный выбор.)

# %%
path, dtw_dist = dtw_alignment_path(a, b, window=0.1)
print(f"DTW distance between a and b is {dtw_dist}.")
# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=0.1)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance between a and b is 1.1985498275436108.

# %% [markdown]
# Важно знать, что  DTW может быть более терпимой и предоставлять более широкие возможности выравнивания временных рядов. Чтобы контролировать такое поведение, мы определяем еще одно ограничение: размер окна.
#
# Это ограничение окон позволяет избежать выравнивания точек, разделенных более чем определенным процентом от длины временного ряда. Другими словами, если ограничение окна равно $w$, выравнивание $i$-й точки можно выполнить только с точками из интервала
#
# $[i - \lfloor w*m \rfloor, i + \lfloor w*m \rfloor]$.
#
# В предыдущем сценарии не использовался размер окна (эквивалент ограничения окна $w=1$.).
#
# Теперь, если мы уменьшим длину окна до $w=0,5$, мы увидим, что путь изменился:

# %%
w = 0.5
path, dtw_dist = dtw_alignment_path(a, b, window=w)
print(f"DTW distance with {w=} between a and b is {dtw_dist}.")

# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=w)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance with w=0.5 between a and b is 0.8566491595090396.

# %% [markdown]
# Посмотрим, что будет при ограничении окна в 20%.

# %%
w = 0.2
path, dtw_dist = dtw_alignment_path(a, b, window=w)
print(f"DTW distance with {w=} between a and b is {dtw_dist}.")

# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=w)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance with w=0.2 between a and b is 0.9199809594402144.

# %% [markdown]
# Можем посмотреть, какие варианты DTW реализованы в aeon. И сравнить получаемые расстояния.

# %%
from aeon.distances._distance import DISTANCES

# These are the DTW variants available in aeon for time series:
dtw_variants = [d["name"] for d in DISTANCES if 'dtw' in d["name"]]
print(f"DTW variants available in aeon: {dtw_variants}")
# Out:
# DTW variants available in aeon: ['dtw', 'dtw_gi', 'ddtw', 'wdtw', 'wddtw', 'adtw', 'shape_dtw', 'soft_dtw']

# %%
from aeon.distances import get_distance_function

for variant in dtw_variants:
    distance_function = get_distance_function(variant)
    distance = distance_function(a, b, window=0.2)
    print(f"{variant} distance between a and b is {distance}")
# Out:
# dtw distance between a and b is 0.9199809594402144
# dtw_gi distance between a and b is 0.9199809594402144
# ddtw distance between a and b is 0.31002884948727205
# wdtw distance between a and b is 0.41867594005282865
# wddtw distance between a and b is 0.13960840776560768
# adtw distance between a and b is 1.5295335354191664
# shape_dtw distance between a and b is 1.5295335354191666
# soft_dtw distance between a and b is 11.074455734012375

# %% [markdown]
# Посмотрим, какие вообще метрики расстояния раелизованы в aeon и сравним их.

# %%
for dist in DISTANCES:
    try:
        print(f"{dist['name']} distance between a and b is {dist['distance'](a, b)}")
    except TypeError as err:
        print(f"{dist['name']} - {err}")
# Out:
# euclidean distance between a and b is 1.236743116180222
# squared distance between a and b is 1.5295335354191664
# manhattan distance between a and b is 3.3323904398054873
# minkowski distance between a and b is 1.2367431161802223
# dtw distance between a and b is 0.6574923997015053
# dtw_gi distance between a and b is 0.6574923997015053
# ddtw distance between a and b is 0.31002884948727205
# wdtw distance between a and b is 0.3235461427240929
# wddtw distance between a and b is 0.13960840776560768
# lcss distance between a and b is 0.0
# erp distance between a and b is 3.021868759085019
# edr distance between a and b is 0.8
# twe distance between a and b is 6.5094056644333955
# msm distance between a and b is 3.3323904398054873
# adtw distance between a and b is 1.5295335354191664
# shape_dtw distance between a and b is 1.5295335354191666
# soft_dtw distance between a and b is 11.740090024872542
# sbd distance between a and b is 0.3633143104636234
# shift_scale distance between a and b is 0.5568073651552791
# dft_sfa - not enough arguments: expected 3, got 2
# paa_sax - not enough arguments: expected 4, got 2
# sax - not enough arguments: expected 4, got 2
# sfa - not enough arguments: expected 3, got 2
# mpdist distance between a and b is 3.650024149988857e-08

# %% [markdown]
# # Distance-based  Time Series Classification (TSC) <a id="classification"></a>
#
# ## Univariate Time Series
#
# Одним из первых способов классификации набора временных рядов является использование k-ближайшего
# подход соседей (kNN) в сочетании с соответствующей мерой расстояния временного ряда.
#
# Самый простой способ — использовать подход kNN «scikit-learn» в сочетании с определением расстояний.
# реализовано в `aeon`. Есть два разных способа:
#
# 1. Передайте функцию расстояния как вызываемую для параметра «метрика» в конструкторе.
#
# или
#
# 2. Установите в конструкторе для метрики значение «предварительно вычисленное» и передайте попарное расстояние.
# матрица для «подгонки» и «предсказания».
#
#
#
# В этом примере мы загружаем набор данных о прицеле, используя двумерный массив numpy, который имеет два размера (n_cases, n_timepoints), учитывая, что это принятый формат `scikit-learn`.
# Несмотря на то, что `aeon` позволяет использовать 2D-массивы, обычно предпочитает 3D-массивы в форма (n_cases, n_channels, n_timepoints).

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=3, metric=dtw_distance)
knn.fit(X_train_utsc, y_train_utsc)
predictions_utsc = knn.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, predictions_utsc)
print(f"Accuracy of 1-NN (sklearn) with DTW is {accuracy}")
# Out:
# Accuracy of 1-NN (sklearn) with DTW is 0.575

# %%
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier

knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=3, distance=dtw_distance)
knn_aeon.fit(X_train_utsc, y_train_utsc)
predictions_utsc_aeon = knn_aeon.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, predictions_utsc_aeon)
print(f"Accuracy of 1-NN (aeon) with DTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with DTW is 0.575

# %% [markdown]
# ## Distance-based Multivariate TSC (MTSC)
#
#
# Версия scikit-learn kNN не может быть применена к трехмерным массивам numpy. Однако, как мы только что видели, существует способ, которым расстояния временных рядов могут быть связаны с scikit-learn kNN: использование заранее вычисленных парных расстояний (в данном случае с расстоянием ADTW, чтобы показать разнообразие расстояний, включенных в `aeon`):

# %%
from aeon.distances import adtw_pairwise_distance, adtw_distance


train_dists = adtw_pairwise_distance(X_train_mtsc)
test_dists = adtw_pairwise_distance(X_test_mtsc, X_train_mtsc)

# scikit-learn KNN classifier with precomputed distances
knn = KNeighborsClassifier(metric="precomputed", n_neighbors=1)
knn.fit(train_dists, y_train_mtsc)
predictions_mtsc = knn.predict(test_dists)

print(
    f"Accuracy of 1-NN (sklearn) with ADTW using precomputed distances is",
    f"{accuracy_score(y_test_mtsc, predictions_mtsc)}"
)
# Out:
# Accuracy of 1-NN (sklearn) with ADTW using precomputed distances is 0.525

# %% [markdown]
# Теперь, если мы запустим подход kNN, специфичный для временных рядов, включенный в `aeon`, нам не нужно предварительно вычислять матрицу попарных расстояний, которая иногда может требовать больших вычислительных ресурсов и памяти.
#
# Для тех расстояний, которые уже реализованы в `aeon`, мы можем использовать их идентификатор вместо вызываемого расстояния. Например, расстояние ADTW обозначается как `adtw`.

# %%
knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=1, distance=adtw_distance)
knn_aeon.fit(X_train_mtsc, y_train_mtsc)
predictions_mtsc_aeon = knn_aeon.predict(X_test_mtsc)

accuracy = accuracy_score(y_test_mtsc, predictions_mtsc_aeon)
print(f"Accuracy of 1-NN (aeon) with ADTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with ADTW is 0.525

# %%
knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=1, distance="adtw")
knn_aeon.fit(X_train_mtsc, y_train_mtsc)
predictions_mtsc_aeon = knn_aeon.predict(X_test_mtsc)

accuracy = accuracy_score(y_test_mtsc, predictions_mtsc_aeon)
print(f"Accuracy of 1-NN (aeon) with ADTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with ADTW is 0.525

# %% [markdown]
# # Distance-based  Time Series Extrinsic Regression <a id='regres'></a>
#
# ## Univariate Time Series Extrinsic Regression (TSER)
#
# Рассмотрим два подхода к регрессии на основе двух метрик расстояния MSM и TWE.

# %%
from aeon.distances import (
    msm_pairwise_distance,
    twe_pairwise_distance,
)
from aeon.regression.distance_based import KNeighborsTimeSeriesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

train_dists = msm_pairwise_distance(X_train_utser)
test_dists = msm_pairwise_distance(X_test_utser, X_train_utser)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_utser)
predictions_utser = knn.predict(test_dists)

mse = mean_squared_error(y_test_utser, predictions_utser)
print(f"MSE of 1-NN (sklearn) with MSM is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="msm")
knn_aeon.fit(X_train_utser, y_train_utser)
predictions_utser_aeon = knn_aeon.predict(X_test_utser)

mse = mean_squared_error(y_test_utser, predictions_utser_aeon)
print(f"MSE of 1-NN (aeon) with MSM is {mse}")
# Out:
# MSE of 1-NN (sklearn) with MSM is 1.3942060469112671
# MSE of 1-NN (aeon) with MSM is 1.3942060469112671

# %%
# Now, for the TWE distance:
train_dists = twe_pairwise_distance(X_train_utser, window=0.1)
test_dists = twe_pairwise_distance(X_test_utser, X_train_utser, window=0.1)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_utser)
predictions_utser = knn.predict(test_dists)

mse = mean_squared_error(y_test_utser, predictions_utser)
print(f"MSE of 1-NN (sklearn) with TWE is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(
    n_neighbors=1,
    distance="twe",
    distance_params={"window": 0.1}
)
knn_aeon.fit(X_train_utser, y_train_utser)
predictions_utser_aeon = knn_aeon.predict(X_test_utser)

mse = mean_squared_error(y_test_utser, predictions_utser_aeon)
print(f"MSE of 1-NN (aeon) with TWE is {mse}")
# Out:
# MSE of 1-NN (sklearn) with TWE is 1.7049822984745453
# MSE of 1-NN (aeon) with TWE is 1.7049822984745453

# %% [markdown]
# ## Distance-based Multivariate TSER (MTSER)

# %%
from aeon.distances import (
    erp_pairwise_distance,
    wdtw_pairwise_distance,
)
from aeon.regression.distance_based import KNeighborsTimeSeriesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error


train_dists = erp_pairwise_distance(X_train_mtser)
test_dists = erp_pairwise_distance(X_test_mtser, X_train_mtser)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_mtser)
predictions_mtser = knn.predict(test_dists)

mse = mean_squared_error(y_test_mtser, predictions_mtser)
print(f"MSE of 1-NN (sklearn) with ERP is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="erp")
knn_aeon.fit(X_train_mtser, y_train_mtser)
predictions_mtser_aeon = knn_aeon.predict(X_test_mtser)

mse = mean_squared_error(y_test_mtser, predictions_mtser_aeon)
print(f"MSE of 1-NN (aeon) with ERP is {mse}")
# Out:
# MSE of 1-NN (sklearn) with ERP is 1.0155583588945694
# MSE of 1-NN (aeon) with ERP is 1.0155583588945694

# %%
# Now, for the wdtw distance:
train_dists = wdtw_pairwise_distance(X_train_mtser, window=0.1)
test_dists = wdtw_pairwise_distance(X_test_mtser, X_train_mtser, window=0.1)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_mtser)
predictions_mtser = knn.predict(test_dists)

mse = mean_squared_error(y_test_mtser, predictions_mtser)
print(f"MSE of 1-NN (sklearn) with WDTW is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(
    n_neighbors=1,
    distance="wdtw",
    distance_params={"window": 0.1}
)
knn_aeon.fit(X_train_mtser, y_train_mtser)
predictions_mtser_aeon = knn_aeon.predict(X_test_mtser)

mse = mean_squared_error(y_test_mtser, predictions_mtser_aeon)
print(f"MSE of 1-NN (aeon) with WDTW is {mse}")
# Out:
# MSE of 1-NN (sklearn) with WDTW is 1.3909486821400647
# MSE of 1-NN (aeon) with WDTW is 1.3909486821400647

# %% [markdown]
# ## Elastic Ensemble (EE) и Proximity Forest (PF)
#
# Другими более продвинутыми подходами являются EE и PF.
#
# EE представляет собой взвешенный ансамбль из 11 классификаторов 1-NN с рядом эластичных мер расстояния. Это требует перекрестной проверки весов каждого классификатора в ансамбле.
#
# В случае PF алгоритм представляет собой ансамбль высокорандомизированных деревьев близости, которые разветвляются по близости временных рядов к тому или иному образцовому временному ряду, а не по значениям атрибутов.

# %%
from aeon.classification.distance_based import ElasticEnsemble

ee = ElasticEnsemble(
    proportion_of_param_options=0.1,
    proportion_train_in_param_finding=0.3,
    proportion_train_for_test=0.5,
)
ee.fit(X_train_utsc, y_train_utsc)
ee_preds = ee.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, ee_preds)
print(f"Accuracy of Elastic Ensemble is {accuracy}.")
# Out:
# Accuracy of Elastic Ensemble is 0.5.

# %% [markdown]
# Более конкретно, реализация EE в `aeon` позволяет выбирать заданные меры расстояния для построения ансамбля, а также изменять некоторые параметры процедуры перекрестной проверки:

# %%
ee = ElasticEnsemble(
    distance_measures=["dtw", "msm"],
    proportion_of_param_options=0.1,
    proportion_train_in_param_finding=0.3,
    proportion_train_for_test=0.5,
)
ee.fit(X_train_utsc, y_train_utsc)
ee_preds = ee.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, ee_preds)
print(f"Accuracy of Elastic Ensemble with DTW and MSM is {accuracy}.")
# Out:
# Accuracy of Elastic Ensemble with DTW and MSM is 0.55.

# %% [markdown]
# Подход PF недавно был включен в `aeon` и на данный момент может решать только одномерные задачи TSC:

# %%
from aeon.classification.distance_based import ProximityForest

pf = ProximityForest(n_trees=10, random_state=0)
pf.fit(X_train_utsc, y_train_utsc)
pf_preds = pf.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, pf_preds)
print(f"Accuracy of Proximity Forest is {accuracy}.")
# Out:
# Accuracy of Proximity Forest is 0.525.

# %% [markdown]
# # Подходы, основанные на свертках <a id='conv'></a>
#
# ### Rocket
#
# RocketClassifier()
# Rocket — оригинальный сверточный метод классификации временных рядов.
#
# ### MiniRocket
# RocketClassifier(rocket_transform = "minirocket") — модификация Rocket, более точная.
#
# ###  Hydra
# HydraClassifier()
# HydraRegressor()
#
# Hydra — это вариант Rocket, который объединяет функции и методы подходов на основе словаря.
#
# Примечание. Гидра реализована с использованием torch. Для запуска этого кода вам понадобится установить его.
# pip install torch.
#
#
# ###  MultiRocket+Hydra
# MultiRocketHydraClassifier()
# MultiRocket+Hydra сочетает в себе подходы MultiRocket и Hydra.

# %%
from aeon.classification.convolution_based import RocketClassifier

classifier = RocketClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.425

# %%
from aeon.classification.convolution_based import MiniRocketClassifier

classifier = MiniRocketClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.9

# %%
from aeon.classification.convolution_based import  HydraClassifier

classifier = HydraClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.925

# %%
from aeon.classification.convolution_based import  MultiRocketHydraClassifier

classifier = MultiRocketHydraClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.8

# %%
from aeon.regression.convolution_based import MiniRocketRegressor
from sklearn.metrics import r2_score

regressor = MiniRocketRegressor(n_jobs=-1, random_state=42)
regressor.fit(X_train_mtser, y_train_mtser)
preds = regressor.predict(X_test_mtser)
r2_score(y_test_mtser, preds)
# Out:
# 0.4110569698148919

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, preds)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: xlabel='Actual values', ylabel='Predicted values'>)

# %%
# FineTuning parameters 

from sklearn.model_selection import GridSearchCV
import numpy as np
import matplotlib.pyplot as plt
from aeon.regression.convolution_based import MiniRocketRegressor

# ==============================================================================
# == fit =======================================================================
# ==============================================================================

param_grid = {
    "n_kernels" : [100, 1000, 10000],
    "max_dilations_per_kernel" : [16, 32, 64],
}

gs = GridSearchCV(
    MiniRocketRegressor(n_jobs=-1, random_state=42),
    param_grid,
)
gs.fit(X_train_mtser, y_train_mtser)

# ==============================================================================
# == plot results ==============================================================
# ==============================================================================

_scores = gs.cv_results_["mean_test_score"]
_params = np.array([f"d={_[0]}\nk={_[1]}" for _ in [tuple(_.values()) for _ in gs.cv_results_["params"]]])
_order = _scores.argsort()
_, a = plt.subplots(1, 1, figsize = (6, 4))
a.plot(_params[_order], _scores[_order], ".-")
a.set(xlabel = "d/k", ylabel = "r2")
plt.show()

# %%
# считаем скор для лучшей конфигурации
gs.score(X_test_mtser, y_test_mtser)
# Out:
# 0.39129226372986725

# %%
# смотри лучший набор

gs
# Out:
# GridSearchCV(estimator=MiniRocketRegressor(n_jobs=-1, random_state=42),
#              param_grid={'max_dilations_per_kernel': [16, 32, 64],
#                          'n_kernels': [100, 1000, 10000]})

# %% [markdown]
# # Feature based classification and regression <a id='feature'></a>
#
# Классификаторы и регрессоры на основе признаков являются популярной темой в классификации временных рядов (TSC) и регрессии (TSER).  В пригципе все такие модели представляют собой пайплайны из вытаскивателей фич и классификаторов/регрессоров.
#
# <img src="data/aeon/pipeline.png" alt="Pipeline classifier."><img>

# %%
# отрисуем наши данные 

from aeon.visualisation import plot_collection_by_class

plot_collection_by_class(X_train_mtsc[:,2,:], y_train_mtsc)
# Out:
# (<Figure size 1200x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
from matplotlib import pyplot as plt

plt.plot(X_train_mtser[0].T)
plt.legend(["Dim 0", "Dim 1", "Dim 2", "Dim 3"])

# %% [markdown]
# ## Catch22 <a id='catch22'></a>
#
# Набор инструментов для сравнительного анализа временных рядов (hctsa) может создать более 7700 функций для исследовательского анализа временных рядов. К сожалению, в настоящее время в Python не существует полного набора этих функций, заинтересованные пользователи могут ознакомиться с соответствующей публикацией и исходным набором инструментов MATLAB.
#
# Канонические характеристики временных рядов (Catch22) представляют собой 22 характеристики hctsa, которые считаются наиболее дискриминационными из полного набора.
#
# Функции Catch22 были выбраны путем оценки наборов данных UCR. Характеристики hctsa изначально были сокращены: были удалены те, которые чувствительны к среднему значению и дисперсии, а также те, которые невозможно вычислить для более чем 80 % наборов данных UCR. Затем была проведена оценка функций на основе прогнозируемой производительности. Любые функции, производительность которых была ниже порогового значения, были удалены. Для остальных признаков была выполнена иерархическая кластеризация корреляционной матрицы для устранения избыточности. Из каждого из 22 сформированных кластеров был выбран один признак с учетом сбалансированной точности, вычислительной эффективности и интерпретируемости. Функции Catch22 охватывают широкий спектр понятий, таких как базовая статистика значений рядов данных, линейные корреляции и энтропия.
#
#
# <img src="data/aeon/catch22.png" alt="Catch22 extraction process."></img>

# %% [markdown]
# Класс Catch22 преобразует временные ряды в 22 признака.

# %%
from aeon.transformations.collection.feature_based import Catch22


c22 = Catch22()
c22.fit_transform(X_train_mtsc)[:5]
# Out:
# array([[-4.94433107e-06,  6.92507633e-06,  2.98422388e+00,
#          4.00000000e+00, -8.88178420e-16, -1.01000518e-15,
#          0.00000000e+00,  1.60000000e+01,  1.11111111e-01,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          3.84615385e-02, -2.70000000e-01,  5.30000000e-01,
#          1.57359203e-10,  5.00000000e+00,  2.00785293e+00,
#          8.28571429e-01,  6.00000000e-01,  4.90873852e-01,
#          1.40193684e-05,  1.81815758e-06, -1.47671393e-06,
#          3.71562980e+00,  4.00000000e+00, -8.88178420e-16,
#         -5.87837340e-16,  0.00000000e+00,  1.70000000e+01,
#          6.25000000e-02,  0.00000000e+00,  0.00000000e+00,
#          3.00000000e+00,  4.54545455e-02, -2.30000000e-01,
#          4.90000000e-01,  7.77998115e-11,  7.00000000e+00,
#          2.00199666e+00,  8.28571429e-01,  8.28571429e-01,
#          2.94524311e-01,  1.02667064e-05, -6.81925616e-06,
#         -2.74171769e-06,  2.54465362e+00,  5.00000000e+00,
#         -8.88178420e-16, -4.07928862e-16,  0.00000000e+00,
#          1.20000000e+01,  4.00000000e-02,  0.00000000e+00,
#          0.00000000e+00,  4.00000000e+00,  5.26315789e-02,
#         -2.00000000e-01,  8.20000000e-01,  1.04053400e-10,
#          8.00000000e+00,  1.84997494e+00,  8.28571429e-01,
#          8.28571429e-01,  4.41786467e-01,  1.08579400e-05,
#         -4.28629432e-06, -2.09537733e-06,  2.25468230e+00,
#          5.00000000e+00, -8.88178420e-16, -1.96296224e-17,
#          0.00000000e+00,  1.30000000e+01,  6.36574074e-03,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          2.50000000e-01, -9.00000000e-02,  8.00000000e-01,
#          3.78824191e-11,  5.00000000e+00,  1.94369228e+00,
#          1.71428571e-01,  8.00000000e-01,  5.39961237e-01,
#          7.16263022e-06],
#        [-4.93347026e-07, -4.41079953e-06,  9.76550866e-01,
#          5.00000000e+00, -8.88178420e-16, -1.93131216e-15,
#          0.00000000e+00,  1.00000000e+01,  1.47737765e-02,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          2.00000000e-01, -6.00000000e-02, -5.60000000e-01,
#          1.02981595e-10,  6.00000000e+00,  2.08655852e+00,
#          1.71428571e-01,  8.28571429e-01,  7.36310778e-01,
#          1.60656562e-05,  1.06128379e-06,  4.37068609e-06,
#          2.99539703e+00,  1.00000000e+00, -8.88178420e-16,
#          2.19729828e-16,  0.00000000e+00,  1.50000000e+01,
#          2.08333333e-02,  0.00000000e+00,  0.00000000e+00,
#          2.00000000e+00,  8.33333333e-02,  9.00000000e-02,
#         -8.80000000e-01,  8.84485984e-11,  5.00000000e+00,
#          2.05946536e+00,  6.00000000e-01,  3.14285714e-01,
#          2.94524311e-01,  9.62091285e-06, -9.48719145e-06,
#         -5.45880569e-06,  1.78980033e+00,  5.00000000e+00,
#         -8.88178420e-16,  5.16491517e-17,  0.00000000e+00,
#          1.20000000e+01,  6.12182430e-03,  0.00000000e+00,
#          0.00000000e+00,  2.00000000e+00,  6.66666667e-01,
#         -3.00000000e-01, -7.40000000e-01,  7.71939551e-11,
#          6.00000000e+00,  1.96831980e+00,  1.71428571e-01,
#          7.14285714e-01,  6.87223393e-01,  1.48956808e-05,
#         -2.88989693e-06, -4.87479978e-06,  2.21747187e+00,
#          5.00000000e+00, -8.88178420e-16,  7.57005863e-17,
#          0.00000000e+00,  1.20000000e+01,  9.23361034e-03,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          2.00000000e-01, -3.00000000e-02, -7.50000000e-01,
#          3.72808238e-11,  4.00000000e+00,  2.04733206e+00,
#          1.71428571e-01,  6.85714286e-01,  4.41786467e-01,
#          7.52540169e-06],
#        [-6.72778723e-06,  2.23202708e-06,  8.30813700e-01,
#          1.00000000e+00, -8.88178420e-16,  1.16234122e-15,
#          0.00000000e+00,  1.10000000e+01,  1.73611111e-02,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          2.50000000e-01, -3.20000000e-01,  3.40000000e-01,
#          6.56303902e-11,  7.00000000e+00,  2.17460531e+00,
#          7.14285714e-01,  1.71428571e-01,  8.34485549e-01,
#          1.45365247e-05, -1.44995057e-06,  1.93312705e-06,
#          7.17005807e-01,  1.00000000e+00, -8.88178420e-16,
#         -8.69151397e-16,  0.00000000e+00,  1.20000000e+01,
#          4.62962963e-03,  0.00000000e+00,  0.00000000e+00,
#          2.00000000e+00,  1.25000000e-01, -6.00000000e-02,
#          3.20000000e-01,  3.23868358e-11,  4.00000000e+00,
#          2.16552480e+00,  8.00000000e-01,  8.00000000e-01,
#          1.32535940e+00,  1.07278852e-05, -1.83019499e-06,
#          7.62620939e-06,  2.41674894e+00,  5.00000000e+00,
#         -8.88178420e-16,  2.01394617e-16,  0.00000000e+00,
#          2.50000000e+01,  9.23361034e-03,  0.00000000e+00,
#          0.00000000e+00,  5.00000000e+00,  4.00000000e-01,
#         -2.70000000e-01, -3.80000000e-01,  9.72031604e-11,
#          6.00000000e+00,  1.94369228e+00,  8.00000000e-01,
#          7.42857143e-01,  4.41786467e-01,  1.12686720e-05,
#         -3.71330823e-06, -1.98429828e-06,  2.58492491e+00,
#          5.00000000e+00, -8.88178420e-16,  5.66426479e-17,
#          0.00000000e+00,  2.30000000e+01,  8.00000000e-02,
#          0.00000000e+00,  0.00000000e+00,  4.00000000e+00,
#          5.55555556e-02, -3.00000000e-02,  5.60000000e-01,
#          4.52016486e-11,  5.00000000e+00,  1.97770999e+00,
#          7.14285714e-01,  8.28571429e-01,  4.41786467e-01,
#          7.43561030e-06],
#        [ 1.06707589e-06,  5.06165512e-06,  9.40987016e-01,
#          4.00000000e+00, -8.88178420e-16, -1.18293308e-15,
#          0.00000000e+00,  1.20000000e+01,  1.23456790e-02,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          1.00000000e-01, -4.20000000e-01, -2.40000000e-01,
#          8.22614633e-11,  6.00000000e+00,  2.16264604e+00,
#          8.28571429e-01,  3.42857143e-01,  7.36310778e-01,
#          1.43699941e-05, -1.24257183e-06,  1.42709096e-06,
#          2.94247757e+00,  3.00000000e+00, -8.88178420e-16,
#         -2.50000611e-16,  0.00000000e+00,  1.50000000e+01,
#          4.62962963e-03,  0.00000000e+00,  0.00000000e+00,
#          2.00000000e+00,  1.25000000e-01,  2.20000000e-01,
#         -1.10000000e-01,  6.93500440e-11,  5.00000000e+00,
#          1.92542785e+00,  8.28571429e-01,  8.28571429e-01,
#          2.94524311e-01,  8.91888264e-06, -4.34236854e-06,
#         -1.88361756e-06,  2.63896118e+00,  4.00000000e+00,
#         -8.88178420e-16, -5.92485890e-16,  0.00000000e+00,
#          1.50000000e+01,  2.20385675e-02,  0.00000000e+00,
#          0.00000000e+00,  3.00000000e+00,  1.11111111e-01,
#          2.90000000e-01, -2.50000000e-01,  6.96738164e-11,
#          6.00000000e+00,  2.00650422e+00,  8.28571429e-01,
#          8.28571429e-01,  3.43611696e-01,  9.74783003e-06,
#         -3.57222777e-06, -5.38267251e-06,  3.04652712e+00,
#          1.10000000e+01, -8.88178420e-16,  4.38125672e-17,
#          0.00000000e+00,  1.40000000e+01,  5.10204082e-03,
#          0.00000000e+00,  0.00000000e+00,  5.00000000e+00,
#          1.42857143e-01,  2.80000000e-01, -1.40000000e-01,
#          4.00538711e-11,  7.00000000e+00,  2.04099986e+00,
#          7.71428571e-01,  2.00000000e-01,  3.43611696e-01,
#          6.30681363e-06],
#        [ 5.41709902e-06,  2.05431239e-06,  8.54785389e-01,
#          3.00000000e+00, -8.88178420e-16, -1.76750953e-15,
#          0.00000000e+00,  1.00000000e+01,  3.67309458e-03,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          3.33333333e-01,  2.08166817e-17, -6.20000000e-01,
#          5.81324313e-11,  5.00000000e+00,  2.15525567e+00,
#          7.71428571e-01,  3.71428571e-01,  1.07992247e+00,
#          1.58005635e-05, -5.96238663e-07,  2.76329744e-06,
#          7.96695469e-01,  2.00000000e+00, -8.88178420e-16,
#         -5.99472331e-16,  0.00000000e+00,  9.00000000e+00,
#          1.93905817e-02,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  2.00000000e-01, -2.00000000e-02,
#         -5.50000000e-01,  3.29836877e-11,  5.00000000e+00,
#          2.14756047e+00,  8.00000000e-01,  8.28571429e-01,
#          1.27627202e+00,  1.12504263e-05,  5.73291371e-06,
#          2.48495087e-06,  1.59802527e+00,  4.00000000e+00,
#         -8.88178420e-16, -5.00682720e-16,  0.00000000e+00,
#          8.00000000e+00,  3.36700337e-03,  0.00000000e+00,
#          0.00000000e+00,  2.00000000e+00,  3.33333333e-01,
#         -1.90000000e-01,  6.90000000e-01,  4.75743565e-11,
#          6.00000000e+00,  2.11236435e+00,  1.71428571e-01,
#          8.28571429e-01,  6.38136008e-01,  1.26219064e-05,
#         -1.88620306e-07,  1.45344422e-06,  1.46937513e+00,
#          5.00000000e+00, -8.88178420e-16, -3.32636878e-17,
#          0.00000000e+00,  1.70000000e+01,  5.20355066e-03,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          3.33333333e-01,  8.00000000e-02, -1.50000000e-01,
#          2.18684364e-11,  5.00000000e+00,  2.03344937e+00,
#          1.71428571e-01,  8.28571429e-01,  6.38136008e-01,
#          7.81002358e-06]])

# %%
from aeon.transformations.collection.feature_based._catch22 import feature_names

feature_names
# Out:
# ['DN_HistogramMode_5',
#  'DN_HistogramMode_10',
#  'CO_f1ecac',
#  'CO_FirstMin_ac',
#  'CO_HistogramAMI_even_2_5',
#  'CO_trev_1_num',
#  'MD_hrv_classic_pnn40',
#  'SB_BinaryStats_mean_longstretch1',
#  'SB_TransitionMatrix_3ac_sumdiagcov',
#  'PD_PeriodicityWang_th0_01',
#  'CO_Embed2_Dist_tau_d_expfit_meandiff',
#  'IN_AutoMutualInfoStats_40_gaussian_fmmi',
#  'FC_LocalSimple_mean1_tauresrat',
#  'DN_OutlierInclude_p_001_mdrmd',
#  'DN_OutlierInclude_n_001_mdrmd',
#  'SP_Summaries_welch_rect_area_5_1',
#  'SB_BinaryStats_diff_longstretch0',
#  'SB_MotifThree_quantile_hh',
#  'SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1',
#  'SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1',
#  'SP_Summaries_welch_rect_centroid',
#  'FC_LocalSimple_mean3_stderr']

# %% [markdown]
# Преобразование можно настроить, и вы можете выбрать подмножество функций для извлечения. Параметр catch24 будет включать среднее и стандартное отклонение, а также исходные 22 функции.
#
# pycatch22 будет использовать библиотеку pycatch22, завернутую в C.

# %%
c22 = Catch22(
    features=["DN_HistogramMode_5", "CO_f1ecac", "SB_MotifThree_quantile_hh", "Mean", "StandardDeviation"],
    catch24=True,
)
c22.fit_transform(X_train_mtsc)[:5]
# Out:
# array([[-4.94433107e-06,  2.98422388e+00,  2.00785293e+00,
#         -4.84662295e-06,  1.63624369e-05,  1.81815758e-06,
#          3.71562980e+00,  2.00199666e+00,  4.07268745e-07,
#          1.16629572e-05, -6.81925616e-06,  2.54465362e+00,
#          1.84997494e+00, -2.73869572e-06,  1.30628441e-05,
#         -4.28629432e-06,  2.25468230e+00,  1.94369228e+00,
#         -3.51260400e-06,  8.11090668e-06],
#        [-4.93347026e-07,  9.76550866e-01,  2.08655852e+00,
#          1.43118551e-06,  1.57514418e-05,  1.06128379e-06,
#          2.99539703e+00,  2.05946536e+00,  4.93131265e-06,
#          1.18989896e-05, -9.48719145e-06,  1.78980033e+00,
#          1.96831980e+00, -3.01206374e-06,  1.42330289e-05,
#         -2.88989693e-06,  2.21747187e+00,  2.04733206e+00,
#         -2.96546855e-06,  8.23176010e-06],
#        [-6.72778723e-06,  8.30813700e-01,  2.17460531e+00,
#         -6.06350354e-07,  1.33059491e-05, -1.44995057e-06,
#          7.17005807e-01,  2.16552480e+00,  3.79695308e-06,
#          1.00766877e-05, -1.83019499e-06,  2.41674894e+00,
#          1.94369228e+00,  3.37033758e-06,  1.24823971e-05,
#         -3.71330823e-06,  2.58492491e+00,  1.97770999e+00,
#          8.40880283e-07,  8.31148145e-06],
#        [ 1.06707589e-06,  9.40987016e-01,  2.16264604e+00,
#         -2.17892949e-07,  1.41719989e-05, -1.24257183e-06,
#          2.94247757e+00,  1.92542785e+00, -2.02235649e-06,
#          1.04135837e-05, -4.34236854e-06,  2.63896118e+00,
#          2.00650422e+00, -2.30261793e-06,  1.08641355e-05,
#         -3.57222777e-06,  3.04652712e+00,  2.04099986e+00,
#         -2.96036604e-06,  7.47429838e-06],
#        [ 5.41709902e-06,  8.54785389e-01,  2.15525567e+00,
#          3.07705341e-06,  1.41351503e-05, -5.96238663e-07,
#          7.96695469e-01,  2.14756047e+00,  8.81621473e-09,
#          1.01270483e-05,  5.73291371e-06,  1.59802527e+00,
#          2.11236435e+00,  2.83706608e-06,  1.17155555e-05,
#         -1.88620306e-07,  1.46937513e+00,  2.03344937e+00,
#         -8.22774051e-07,  7.29112178e-06]])

# %% [markdown]
# Классы Catch22Classifier и Catch22Regressor в aeon — это просто удобные оболочки для конвейера преобразования Catch22 и случайного леса, обучаемого scikit-learn по умолчанию.

# %%
from aeon.classification.feature_based import Catch22Classifier
from sklearn.metrics import accuracy_score

c22_cls = Catch22Classifier(random_state=42)
c22_cls.fit(X_train_mtsc, y_train_mtsc)
c22_preds_c = c22_cls.predict(X_test_mtsc)
accuracy_score(y_test_mtsc, c22_preds_c)
# Out:
# 0.875

# %%
from aeon.classification.sklearn import RotationForestClassifier

c22_cls = Catch22Classifier(
    features=["DN_HistogramMode_5", "CO_f1ecac", "SB_MotifThree_quantile_hh", "Mean", "StandardDeviation"],
    estimator=RotationForestClassifier(),
    random_state=42,
)
c22_cls.fit(X_train_mtsc, y_train_mtsc)
c22_preds_c = c22_cls.predict(X_test_mtsc)
accuracy_score(y_test_mtsc, c22_preds_c)
# Out:
# 0.9

# %%
from aeon.regression.feature_based import Catch22Regressor
from sklearn.metrics import mean_squared_error

c22_reg = Catch22Regressor(random_state=42)
c22_reg.fit(X_train_mtser, y_train_mtser)
c22_preds_r = c22_reg.predict(X_test_mtser)
mean_squared_error(y_test_mtser, c22_preds_r)
# Out:
# 0.7975235446926242

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, c22_preds_r)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# # Deep Leaning подходы <a id='deep'></a>
#
# Можно сказать, что на данном этапе модели глубокого обучения являются SOTA моделями для решения задач классификации и регрессии временных рядов.
#
#
# <img src="data/aeon/deep-legend.png" alt="Deep Legend."></img>

# %%
# Для классификации
# нормализуем по среднему и дисперсии наши ряды 
X_train_c = (X_train_mtsc - X_train_mtsc.mean(axis=-1, keepdims=True)) / (X_train_mtsc.std(axis=-1, keepdims=True))
X_test_c = (X_test_mtsc - X_test_mtsc.mean(axis=-1, keepdims=True)) / (X_test_mtsc.std(axis=-1, keepdims=True))

print("Train shape:", X_train_c.shape)
print("Test shape:", X_test_c.shape)
# Out:
# Train shape: (40, 4, 100)
# Test shape: (40, 4, 100)

# %%
from aeon.visualisation import plot_collection_by_class

plot_collection_by_class(X_train_c[:,0,:], y_train_mtsc)
# Out:
# (<Figure size 1200x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
# для регрессии

# znormalize the series
X_train_r = (X_train_mtser - X_train_mtser.mean(axis=-1, keepdims=True)) / (X_train_mtser.std(axis=-1, keepdims=True))
X_test_r = (X_test_mtser - X_test_mtser.mean(axis=-1, keepdims=True)) / (X_test_mtser.std(axis=-1, keepdims=True))

print("Train shape:", X_train_mtser.shape)
print("Test shape:", X_test_mtser.shape)
# Out:
# Train shape: (72, 4, 100)
# Test shape: (72, 4, 100)

# %%
from matplotlib import pyplot as plt

plt.plot(X_train_r[:5,0,:].T)
plt.title("EEG Regression Samples")
plt.xlabel("Time")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## Multi Layer Perceptron (MLP)
#
#
# Многослойный персептрон (MLP), простейшая модель нейронных сетей, часто используется в качестве основы для моделей глубокого обучения. Однако применительно к данным временных рядов он не учитывает временные зависимости. Модель MLP пытается найти оптимальную нелинейную комбинацию входных функций для достижения хорошей производительности последующей задачи.
#
# <img src="data/aeon/MLP.png" alt="mlp"><i>

# %%
import tensorflow as tf
from aeon.classification.deep_learning import MLPClassifier
from sklearn.metrics import accuracy_score

mlp_cls = MLPClassifier(n_epochs=100)
mlp_cls.fit(X_train_c, y_train_mtsc)
mlp_cls_preds = mlp_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, mlp_cls_preds))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 0.525

# %%
import tensorflow as tf
from aeon.regression.deep_learning import MLPRegressor
from sklearn.metrics import mean_squared_error

mlp_rgs = MLPRegressor(n_epochs=500)
mlp_rgs.fit(X_train_r, y_train_mtser)
mlp_rgs_preds = mlp_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, mlp_rgs_preds))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1.6786026180791813

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, mlp_rgs_preds, title="MLP Predictions")
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'MLP Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# ## The Fully Convolutional Neural Network (FCNRegressor)
#
#
# Полностью сверточные нейронные сети (FCN) все чаще используются для анализа временных рядов благодаря их способности эффективно улавливать локальные закономерности и многомасштабные зависимости.
#
# Сверточная нейронная сеть по времени (TimeCNN) — это сверточная нейронная сеть, в которой процесс оптимизации фокусируется на изучении наиболее эффективных фильтров для достижения оптимальных результатов. В отличие от MLP, TimeCNN использует локальные свертки, позволяя улавливать и учитывать временные зависимости в данных, что делает их более подходящими для анализа временных рядов.
#
# <img src="data/aeon/TimeCNN.png" alt="cnn"><i>

# %%
import tensorflow as tf
from aeon.classification.deep_learning import FCNClassifier
from sklearn.metrics import accuracy_score

# n_epochs chooses the number of training iterations
# verbose show the network's detail and the logs of training
cnn_cls = FCNClassifier(n_epochs=500, verbose=True, save_best_model=True, best_file_name="best_cnn")
cnn_cls.fit(X_train_c, y_train_mtsc)
cnn_cls_preds = cnn_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, cnn_cls_preds))
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 100, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 100, 128)       │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 100, 256)       │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 100, 128)       │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 269,058 (1.03 MB)
#  Trainable params: 268,034 (1.02 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.5469 - loss: 0.6212 - learning_rate: 0.0010
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9594 - loss: 0.1969 - learning_rate: 0.0010
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.1052 - learning_rate: 0.0010
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0641 - learning_rate: 0.0010
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0442 - learning_rate: 0.0010
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0328 - learning_rate: 0.0010
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0258 - learning_rate: 0.0010
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0213 - learning_rate: 0.0010
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0179 - learning_rate: 0.0010
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0152 - learning_rate: 0.0010
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0132 - learning_rate: 0.0010
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0117 - learning_rate: 0.0010
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0105 - learning_rate: 0.0010
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0095 - learning_rate: 0.0010
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0087 - learning_rate: 0.0010
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0080 - learning_rate: 0.0010
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0074 - learning_rate: 0.0010
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0069 - learning_rate: 0.0010
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0065 - learning_rate: 0.0010
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0061 - learning_rate: 0.0010
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0058 - learning_rate: 0.0010
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0055 - learning_rate: 0.0010
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0052 - learning_rate: 0.0010
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0050 - learning_rate: 0.0010
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0048 - learning_rate: 0.0010
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0046 - learning_rate: 0.0010
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0044 - learning_rate: 0.0010
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0042 - learning_rate: 0.0010
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0041 - learning_rate: 0.0010
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0039 - learning_rate: 0.0010
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0038 - learning_rate: 0.0010
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0037 - learning_rate: 0.0010
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0035 - learning_rate: 0.0010
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0034 - learning_rate: 0.0010
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0033 - learning_rate: 0.0010
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0032 - learning_rate: 0.0010
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0031 - learning_rate: 0.0010
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0030 - learning_rate: 0.0010
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0029 - learning_rate: 0.0010
# Epoch 40/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0028 - learning_rate: 0.0010
# Epoch 41/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0028 - learning_rate: 0.0010
# Epoch 42/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0027 - learning_rate: 0.0010
# Epoch 43/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0026 - learning_rate: 0.0010
# Epoch 44/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0025 - learning_rate: 0.0010
# Epoch 45/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0025 - learning_rate: 0.0010
# Epoch 46/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0024 - learning_rate: 0.0010
# Epoch 47/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0024 - learning_rate: 0.0010
# Epoch 48/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0023 - learning_rate: 0.0010
# Epoch 49/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0022 - learning_rate: 0.0010
# Epoch 50/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0022 - learning_rate: 0.0010
# Epoch 51/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0021 - learning_rate: 0.0010
# Epoch 52/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0021 - learning_rate: 0.0010
# Epoch 53/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0020 - learning_rate: 0.0010
# Epoch 54/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0020 - learning_rate: 0.0010
# Epoch 55/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0019 - learning_rate: 0.0010
# Epoch 56/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0019 - learning_rate: 0.0010
# Epoch 57/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0019 - learning_rate: 0.0010
# Epoch 58/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0018 - learning_rate: 0.0010
# Epoch 59/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0018 - learning_rate: 0.0010
# Epoch 60/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0017 - learning_rate: 0.0010
# Epoch 61/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0017 - learning_rate: 0.0010
# Epoch 62/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0017 - learning_rate: 0.0010
# Epoch 63/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 64/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 65/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 66/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 67/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 68/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 69/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 70/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 71/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 72/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 73/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 74/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 75/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 76/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 77/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 78/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 79/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 80/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 81/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 82/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 83/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 84/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 85/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 86/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 87/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 88/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 89/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 90/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 91/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 92/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 9.9969e-04 - learning_rate: 0.0010
# Epoch 93/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 9.8522e-04 - learning_rate: 0.0010
# Epoch 94/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 9.7110e-04 - learning_rate: 0.0010
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 9.5729e-04 - learning_rate: 0.0010
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 9.4382e-04 - learning_rate: 0.0010
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 9.3065e-04 - learning_rate: 0.0010
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 9.1778e-04 - learning_rate: 0.0010
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 9.0519e-04 - learning_rate: 0.0010
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 8.9286e-04 - learning_rate: 0.0010
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 8.8079e-04 - learning_rate: 0.0010
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 8.6898e-04 - learning_rate: 0.0010
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 8.5744e-04 - learning_rate: 0.0010
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 8.4612e-04 - learning_rate: 0.0010
# Epoch 105/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 8.3505e-04 - learning_rate: 0.0010
# Epoch 106/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 8.2420e-04 - learning_rate: 0.0010
# Epoch 107/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 8.1358e-04 - learning_rate: 0.0010
# Epoch 108/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 8.0319e-04 - learning_rate: 0.0010
# Epoch 109/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 7.9301e-04 - learning_rate: 0.0010
# Epoch 110/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 7.8301e-04 - learning_rate: 0.0010
# Epoch 111/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 7.7322e-04 - learning_rate: 0.0010
# Epoch 112/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 7.6362e-04 - learning_rate: 0.0010
# Epoch 113/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 7.5422e-04 - learning_rate: 0.0010
# Epoch 114/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 7.4501e-04 - learning_rate: 0.0010
# Epoch 115/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 7.3597e-04 - learning_rate: 0.0010
# Epoch 116/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 7.2709e-04 - learning_rate: 0.0010
# Epoch 117/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 7.1843e-04 - learning_rate: 0.0010
# Epoch 118/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 7.0991e-04 - learning_rate: 0.0010
# Epoch 119/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 7.0154e-04 - learning_rate: 0.0010
# Epoch 120/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 6.9338e-04 - learning_rate: 0.0010
# Epoch 121/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 6.8534e-04 - learning_rate: 0.0010
# Epoch 122/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 6.7746e-04 - learning_rate: 0.0010
# Epoch 123/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 6.6972e-04 - learning_rate: 0.0010
# Epoch 124/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 6.6210e-04 - learning_rate: 0.0010
# Epoch 125/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 6.5464e-04 - learning_rate: 0.0010
# Epoch 126/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 6.4729e-04 - learning_rate: 0.0010
# Epoch 127/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 6.4009e-04 - learning_rate: 0.0010
# Epoch 128/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 6.3300e-04 - learning_rate: 0.0010
# Epoch 129/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 6.2603e-04 - learning_rate: 0.0010
# Epoch 130/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 6.1920e-04 - learning_rate: 0.0010
# Epoch 131/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 6.1249e-04 - learning_rate: 0.0010
# Epoch 132/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 6.0588e-04 - learning_rate: 0.0010
# Epoch 133/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 5.9940e-04 - learning_rate: 0.0010
# Epoch 134/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 5.9301e-04 - learning_rate: 0.0010
# Epoch 135/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 5.8673e-04 - learning_rate: 0.0010
# Epoch 136/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 5.8056e-04 - learning_rate: 0.0010
# Epoch 137/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 5.7449e-04 - learning_rate: 0.0010
# Epoch 138/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 5.6852e-04 - learning_rate: 0.0010
# Epoch 139/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 5.6264e-04 - learning_rate: 0.0010
# Epoch 140/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 5.5686e-04 - learning_rate: 0.0010
# Epoch 141/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 5.5117e-04 - learning_rate: 0.0010
# Epoch 142/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 5.4558e-04 - learning_rate: 0.0010
# Epoch 143/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 5.4008e-04 - learning_rate: 0.0010
# Epoch 144/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 5.3466e-04 - learning_rate: 0.0010
# Epoch 145/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 5.2934e-04 - learning_rate: 0.0010
# Epoch 146/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 5.2408e-04 - learning_rate: 0.0010
# Epoch 147/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 5.1892e-04 - learning_rate: 0.0010
# Epoch 148/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 5.1382e-04 - learning_rate: 0.0010
# Epoch 149/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 5.0882e-04 - learning_rate: 0.0010
# Epoch 150/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 5.0389e-04 - learning_rate: 0.0010
# Epoch 151/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 4.9903e-04 - learning_rate: 0.0010
# Epoch 152/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 4.9424e-04 - learning_rate: 0.0010
# Epoch 153/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 4.8952e-04 - learning_rate: 0.0010
# Epoch 154/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 4.8490e-04 - learning_rate: 0.0010
# Epoch 155/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 4.8031e-04 - learning_rate: 0.0010
# Epoch 156/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 4.7580e-04 - learning_rate: 0.0010
# Epoch 157/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 4.7136e-04 - learning_rate: 0.0010
# Epoch 158/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 4.6697e-04 - learning_rate: 0.0010
# Epoch 159/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 4.6265e-04 - learning_rate: 0.0010
# Epoch 160/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 4.5839e-04 - learning_rate: 0.0010
# Epoch 161/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 4.5419e-04 - learning_rate: 0.0010
# Epoch 162/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 4.5007e-04 - learning_rate: 0.0010
# Epoch 163/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 4.4598e-04 - learning_rate: 0.0010
# Epoch 164/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 4.4197e-04 - learning_rate: 0.0010
# Epoch 165/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 4.3801e-04 - learning_rate: 0.0010
# Epoch 166/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 4.3409e-04 - learning_rate: 0.0010
# Epoch 167/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 4.3026e-04 - learning_rate: 0.0010
# Epoch 168/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 4.2646e-04 - learning_rate: 0.0010
# Epoch 169/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 4.2270e-04 - learning_rate: 0.0010
# Epoch 170/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 4.1902e-04 - learning_rate: 0.0010
# Epoch 171/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 4.1538e-04 - learning_rate: 0.0010
# Epoch 172/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 4.1178e-04 - learning_rate: 0.0010
# Epoch 173/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 4.0821e-04 - learning_rate: 0.0010
# Epoch 174/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 4.0472e-04 - learning_rate: 0.0010
# Epoch 175/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 4.0126e-04 - learning_rate: 0.0010
# Epoch 176/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 3.9784e-04 - learning_rate: 0.0010
# Epoch 177/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.9446e-04 - learning_rate: 0.0010
# Epoch 178/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 3.9113e-04 - learning_rate: 0.0010
# Epoch 179/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 3.8785e-04 - learning_rate: 0.0010
# Epoch 180/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.8460e-04 - learning_rate: 0.0010
# Epoch 181/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 3.8141e-04 - learning_rate: 0.0010
# Epoch 182/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 3.7826e-04 - learning_rate: 0.0010
# Epoch 183/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.7512e-04 - learning_rate: 0.0010
# Epoch 184/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 3.7206e-04 - learning_rate: 0.0010
# Epoch 185/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 3.6902e-04 - learning_rate: 0.0010
# Epoch 186/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 3.6602e-04 - learning_rate: 0.0010
# Epoch 187/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.6306e-04 - learning_rate: 0.0010
# Epoch 188/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.6013e-04 - learning_rate: 0.0010
# Epoch 189/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 3.5725e-04 - learning_rate: 0.0010
# Epoch 190/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 3.5441e-04 - learning_rate: 0.0010
# Epoch 191/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 3.5160e-04 - learning_rate: 0.0010
# Epoch 192/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.4882e-04 - learning_rate: 0.0010
# Epoch 193/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.4608e-04 - learning_rate: 0.0010
# Epoch 194/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.4338e-04 - learning_rate: 0.0010
# Epoch 195/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 3.4069e-04 - learning_rate: 0.0010
# Epoch 196/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 3.3805e-04 - learning_rate: 0.0010
# Epoch 197/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 3.3542e-04 - learning_rate: 0.0010
# Epoch 198/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.3284e-04 - learning_rate: 0.0010
# Epoch 199/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 3.3028e-04 - learning_rate: 0.0010
# Epoch 200/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.2775e-04 - learning_rate: 0.0010
# Epoch 201/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 3.2525e-04 - learning_rate: 0.0010
# Epoch 202/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 3.2277e-04 - learning_rate: 0.0010
# Epoch 203/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 3.2033e-04 - learning_rate: 0.0010
# Epoch 204/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 3.1792e-04 - learning_rate: 0.0010
# Epoch 205/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.1553e-04 - learning_rate: 0.0010
# Epoch 206/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.1317e-04 - learning_rate: 0.0010
# Epoch 207/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.1083e-04 - learning_rate: 0.0010
# Epoch 208/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 3.0852e-04 - learning_rate: 0.0010
# Epoch 209/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 3.0624e-04 - learning_rate: 0.0010
# Epoch 210/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 3.0399e-04 - learning_rate: 0.0010
# Epoch 211/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.0176e-04 - learning_rate: 0.0010
# Epoch 212/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.9955e-04 - learning_rate: 0.0010
# Epoch 213/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.9737e-04 - learning_rate: 0.0010
# Epoch 214/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.9521e-04 - learning_rate: 0.0010
# Epoch 215/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.9308e-04 - learning_rate: 0.0010
# Epoch 216/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 2.9096e-04 - learning_rate: 0.0010
# Epoch 217/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 2.8887e-04 - learning_rate: 0.0010
# Epoch 218/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.8681e-04 - learning_rate: 0.0010
# Epoch 219/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.8476e-04 - learning_rate: 0.0010
# Epoch 220/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.8273e-04 - learning_rate: 0.0010
# Epoch 221/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.8074e-04 - learning_rate: 0.0010
# Epoch 222/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 2.7876e-04 - learning_rate: 0.0010
# Epoch 223/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.7681e-04 - learning_rate: 0.0010
# Epoch 224/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.7487e-04 - learning_rate: 0.0010
# Epoch 225/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 2.7295e-04 - learning_rate: 0.0010
# Epoch 226/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.7107e-04 - learning_rate: 0.0010
# Epoch 227/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.6918e-04 - learning_rate: 0.0010
# Epoch 228/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.6732e-04 - learning_rate: 0.0010
# Epoch 229/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.6550e-04 - learning_rate: 0.0010
# Epoch 230/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 2.6368e-04 - learning_rate: 0.0010
# Epoch 231/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.6187e-04 - learning_rate: 0.0010
# Epoch 232/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.6010e-04 - learning_rate: 0.0010
# Epoch 233/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.5834e-04 - learning_rate: 0.0010
# Epoch 234/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.5660e-04 - learning_rate: 0.0010
# Epoch 235/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.5487e-04 - learning_rate: 0.0010
# Epoch 236/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.5316e-04 - learning_rate: 0.0010
# Epoch 237/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 2.5148e-04 - learning_rate: 0.0010
# Epoch 238/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.4981e-04 - learning_rate: 0.0010
# Epoch 239/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.4815e-04 - learning_rate: 0.0010
# Epoch 240/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.4651e-04 - learning_rate: 0.0010
# Epoch 241/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.4488e-04 - learning_rate: 0.0010
# Epoch 242/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 2.4327e-04 - learning_rate: 0.0010
# Epoch 243/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.4168e-04 - learning_rate: 0.0010
# Epoch 244/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.4011e-04 - learning_rate: 0.0010
# Epoch 245/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.3854e-04 - learning_rate: 0.0010
# Epoch 246/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.3701e-04 - learning_rate: 0.0010
# Epoch 247/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.3548e-04 - learning_rate: 0.0010
# Epoch 248/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.3396e-04 - learning_rate: 0.0010
# Epoch 249/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.3245e-04 - learning_rate: 0.0010
# Epoch 250/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.3096e-04 - learning_rate: 0.0010
# Epoch 251/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 2.2950e-04 - learning_rate: 0.0010
# Epoch 252/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 2.2803e-04 - learning_rate: 0.0010
# Epoch 253/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 2.2659e-04 - learning_rate: 0.0010
# Epoch 254/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 2.2517e-04 - learning_rate: 0.0010
# Epoch 255/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.2374e-04 - learning_rate: 0.0010
# Epoch 256/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 2.2233e-04 - learning_rate: 0.0010
# Epoch 257/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 2.2094e-04 - learning_rate: 0.0010
# Epoch 258/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 2.1957e-04 - learning_rate: 0.0010
# Epoch 259/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.1820e-04 - learning_rate: 0.0010
# Epoch 260/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.1683e-04 - learning_rate: 0.0010
# Epoch 261/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.1549e-04 - learning_rate: 0.0010
# Epoch 262/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.1417e-04 - learning_rate: 0.0010
# Epoch 263/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 2.1285e-04 - learning_rate: 0.0010
# Epoch 264/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.1153e-04 - learning_rate: 0.0010
# Epoch 265/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.1024e-04 - learning_rate: 0.0010
# Epoch 266/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.0897e-04 - learning_rate: 0.0010
# Epoch 267/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.0770e-04 - learning_rate: 0.0010
# Epoch 268/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 2.0643e-04 - learning_rate: 0.0010
# Epoch 269/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 2.0519e-04 - learning_rate: 0.0010
# Epoch 270/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.0396e-04 - learning_rate: 0.0010
# Epoch 271/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.0273e-04 - learning_rate: 0.0010
# Epoch 272/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.0152e-04 - learning_rate: 0.0010
# Epoch 273/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.0032e-04 - learning_rate: 0.0010
# Epoch 274/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 1.9917e-04 - learning_rate: 5.0000e-04
# Epoch 275/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.9858e-04 - learning_rate: 5.0000e-04
# Epoch 276/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.9799e-04 - learning_rate: 5.0000e-04
# Epoch 277/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.9740e-04 - learning_rate: 5.0000e-04
# Epoch 278/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.9681e-04 - learning_rate: 5.0000e-04
# Epoch 279/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.9623e-04 - learning_rate: 5.0000e-04
# Epoch 280/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.9565e-04 - learning_rate: 5.0000e-04
# Epoch 281/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.9507e-04 - learning_rate: 5.0000e-04
# Epoch 282/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.9449e-04 - learning_rate: 5.0000e-04
# Epoch 283/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.9393e-04 - learning_rate: 5.0000e-04
# Epoch 284/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.9336e-04 - learning_rate: 5.0000e-04
# Epoch 285/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.9279e-04 - learning_rate: 5.0000e-04
# Epoch 286/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.9221e-04 - learning_rate: 5.0000e-04
# Epoch 287/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.9165e-04 - learning_rate: 5.0000e-04
# Epoch 288/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.9107e-04 - learning_rate: 5.0000e-04
# Epoch 289/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.9051e-04 - learning_rate: 5.0000e-04
# Epoch 290/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.8995e-04 - learning_rate: 5.0000e-04
# Epoch 291/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.8938e-04 - learning_rate: 5.0000e-04
# Epoch 292/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.8883e-04 - learning_rate: 5.0000e-04
# Epoch 293/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.8828e-04 - learning_rate: 5.0000e-04
# Epoch 294/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.8773e-04 - learning_rate: 5.0000e-04
# Epoch 295/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.8718e-04 - learning_rate: 5.0000e-04
# Epoch 296/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.8662e-04 - learning_rate: 5.0000e-04
# Epoch 297/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.8608e-04 - learning_rate: 5.0000e-04
# Epoch 298/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.8552e-04 - learning_rate: 5.0000e-04
# Epoch 299/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.8498e-04 - learning_rate: 5.0000e-04
# Epoch 300/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.8444e-04 - learning_rate: 5.0000e-04
# Epoch 301/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.8389e-04 - learning_rate: 5.0000e-04
# Epoch 302/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.8335e-04 - learning_rate: 5.0000e-04
# Epoch 303/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.8282e-04 - learning_rate: 5.0000e-04
# Epoch 304/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 1.8228e-04 - learning_rate: 5.0000e-04
# Epoch 305/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.8175e-04 - learning_rate: 5.0000e-04
# Epoch 306/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.8121e-04 - learning_rate: 5.0000e-04
# Epoch 307/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.8068e-04 - learning_rate: 5.0000e-04
# Epoch 308/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.8015e-04 - learning_rate: 5.0000e-04
# Epoch 309/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.7963e-04 - learning_rate: 5.0000e-04
# Epoch 310/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 1.7908e-04 - learning_rate: 5.0000e-04
# Epoch 311/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7856e-04 - learning_rate: 5.0000e-04
# Epoch 312/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7804e-04 - learning_rate: 5.0000e-04
# Epoch 313/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7752e-04 - learning_rate: 5.0000e-04
# Epoch 314/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7701e-04 - learning_rate: 5.0000e-04
# Epoch 315/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.7650e-04 - learning_rate: 5.0000e-04
# Epoch 316/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.7597e-04 - learning_rate: 5.0000e-04
# Epoch 317/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7545e-04 - learning_rate: 5.0000e-04
# Epoch 318/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7494e-04 - learning_rate: 5.0000e-04
# Epoch 319/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.7443e-04 - learning_rate: 5.0000e-04
# Epoch 320/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7392e-04 - learning_rate: 5.0000e-04
# Epoch 321/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.7341e-04 - learning_rate: 5.0000e-04
# Epoch 322/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.7290e-04 - learning_rate: 5.0000e-04
# Epoch 323/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.7239e-04 - learning_rate: 5.0000e-04
# Epoch 324/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.7192e-04 - learning_rate: 2.5000e-04
# Epoch 325/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.7167e-04 - learning_rate: 2.5000e-04
# Epoch 326/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.7142e-04 - learning_rate: 2.5000e-04
# Epoch 327/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.7117e-04 - learning_rate: 2.5000e-04
# Epoch 328/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7092e-04 - learning_rate: 2.5000e-04
# Epoch 329/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.7066e-04 - learning_rate: 2.5000e-04
# Epoch 330/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.7042e-04 - learning_rate: 2.5000e-04
# Epoch 331/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7016e-04 - learning_rate: 2.5000e-04
# Epoch 332/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6992e-04 - learning_rate: 2.5000e-04
# Epoch 333/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.6966e-04 - learning_rate: 2.5000e-04
# Epoch 334/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6942e-04 - learning_rate: 2.5000e-04
# Epoch 335/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6917e-04 - learning_rate: 2.5000e-04
# Epoch 336/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.6892e-04 - learning_rate: 2.5000e-04
# Epoch 337/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6868e-04 - learning_rate: 2.5000e-04
# Epoch 338/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6841e-04 - learning_rate: 2.5000e-04
# Epoch 339/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 1.6817e-04 - learning_rate: 2.5000e-04
# Epoch 340/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6792e-04 - learning_rate: 2.5000e-04
# Epoch 341/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6768e-04 - learning_rate: 2.5000e-04
# Epoch 342/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6743e-04 - learning_rate: 2.5000e-04
# Epoch 343/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.6719e-04 - learning_rate: 2.5000e-04
# Epoch 344/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6693e-04 - learning_rate: 2.5000e-04
# Epoch 345/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6668e-04 - learning_rate: 2.5000e-04
# Epoch 346/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6643e-04 - learning_rate: 2.5000e-04
# Epoch 347/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6619e-04 - learning_rate: 2.5000e-04
# Epoch 348/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6595e-04 - learning_rate: 2.5000e-04
# Epoch 349/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.6569e-04 - learning_rate: 2.5000e-04
# Epoch 350/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.6545e-04 - learning_rate: 2.5000e-04
# Epoch 351/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6520e-04 - learning_rate: 2.5000e-04
# Epoch 352/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.6495e-04 - learning_rate: 2.5000e-04
# Epoch 353/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6470e-04 - learning_rate: 2.5000e-04
# Epoch 354/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6446e-04 - learning_rate: 2.5000e-04
# Epoch 355/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6422e-04 - learning_rate: 2.5000e-04
# Epoch 356/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.6397e-04 - learning_rate: 2.5000e-04
# Epoch 357/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 1.6373e-04 - learning_rate: 2.5000e-04
# Epoch 358/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6347e-04 - learning_rate: 2.5000e-04
# Epoch 359/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6324e-04 - learning_rate: 2.5000e-04
# Epoch 360/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6298e-04 - learning_rate: 2.5000e-04
# Epoch 361/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.6273e-04 - learning_rate: 2.5000e-04
# Epoch 362/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.6249e-04 - learning_rate: 2.5000e-04
# Epoch 363/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.6225e-04 - learning_rate: 2.5000e-04
# Epoch 364/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.6200e-04 - learning_rate: 2.5000e-04
# Epoch 365/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6176e-04 - learning_rate: 2.5000e-04
# Epoch 366/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6152e-04 - learning_rate: 2.5000e-04
# Epoch 367/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.6128e-04 - learning_rate: 2.5000e-04
# Epoch 368/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.6102e-04 - learning_rate: 2.5000e-04
# Epoch 369/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.6079e-04 - learning_rate: 2.5000e-04
# Epoch 370/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 1.6054e-04 - learning_rate: 2.5000e-04
# Epoch 371/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 1.6030e-04 - learning_rate: 2.5000e-04
# Epoch 372/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.6005e-04 - learning_rate: 2.5000e-04
# Epoch 373/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5981e-04 - learning_rate: 2.5000e-04
# Epoch 374/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.5956e-04 - learning_rate: 2.5000e-04
# Epoch 375/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.5934e-04 - learning_rate: 2.5000e-04
# Epoch 376/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.5909e-04 - learning_rate: 2.5000e-04
# Epoch 377/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 1.5884e-04 - learning_rate: 2.5000e-04
# Epoch 378/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5859e-04 - learning_rate: 2.5000e-04
# Epoch 379/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.5835e-04 - learning_rate: 2.5000e-04
# Epoch 380/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.5811e-04 - learning_rate: 2.5000e-04
# Epoch 381/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5787e-04 - learning_rate: 2.5000e-04
# Epoch 382/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5763e-04 - learning_rate: 2.5000e-04
# Epoch 383/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5738e-04 - learning_rate: 2.5000e-04
# Epoch 384/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.5715e-04 - learning_rate: 2.5000e-04
# Epoch 385/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5689e-04 - learning_rate: 2.5000e-04
# Epoch 386/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5666e-04 - learning_rate: 2.5000e-04
# Epoch 387/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.5642e-04 - learning_rate: 2.5000e-04
# Epoch 388/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5619e-04 - learning_rate: 2.5000e-04
# Epoch 389/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.5593e-04 - learning_rate: 2.5000e-04
# Epoch 390/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5570e-04 - learning_rate: 2.5000e-04
# Epoch 391/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.5546e-04 - learning_rate: 2.5000e-04
# Epoch 392/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5521e-04 - learning_rate: 2.5000e-04
# Epoch 393/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.5498e-04 - learning_rate: 2.5000e-04
# Epoch 394/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.5474e-04 - learning_rate: 2.5000e-04
# Epoch 395/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5450e-04 - learning_rate: 2.5000e-04
# Epoch 396/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5427e-04 - learning_rate: 2.5000e-04
# Epoch 397/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5402e-04 - learning_rate: 2.5000e-04
# Epoch 398/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 1.5377e-04 - learning_rate: 2.5000e-04
# Epoch 399/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5355e-04 - learning_rate: 2.5000e-04
# Epoch 400/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.5331e-04 - learning_rate: 2.5000e-04
# Epoch 401/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.5307e-04 - learning_rate: 2.5000e-04
# Epoch 402/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.5284e-04 - learning_rate: 2.5000e-04
# Epoch 403/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.5259e-04 - learning_rate: 2.5000e-04
# Epoch 404/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5236e-04 - learning_rate: 2.5000e-04
# Epoch 405/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5212e-04 - learning_rate: 2.5000e-04
# Epoch 406/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5189e-04 - learning_rate: 1.2500e-04
# Epoch 407/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.5176e-04 - learning_rate: 1.2500e-04
# Epoch 408/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.5165e-04 - learning_rate: 1.2500e-04
# Epoch 409/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5152e-04 - learning_rate: 1.2500e-04
# Epoch 410/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.5141e-04 - learning_rate: 1.2500e-04
# Epoch 411/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 1.5129e-04 - learning_rate: 1.2500e-04
# Epoch 412/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5119e-04 - learning_rate: 1.2500e-04
# Epoch 413/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5106e-04 - learning_rate: 1.2500e-04
# Epoch 414/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.5094e-04 - learning_rate: 1.2500e-04
# Epoch 415/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.5082e-04 - learning_rate: 1.2500e-04
# Epoch 416/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.5071e-04 - learning_rate: 1.2500e-04
# Epoch 417/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.5058e-04 - learning_rate: 1.2500e-04
# Epoch 418/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.5046e-04 - learning_rate: 1.2500e-04
# Epoch 419/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.5034e-04 - learning_rate: 1.2500e-04
# Epoch 420/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.5023e-04 - learning_rate: 1.2500e-04
# Epoch 421/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 1.5010e-04 - learning_rate: 1.2500e-04
# Epoch 422/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4999e-04 - learning_rate: 1.2500e-04
# Epoch 423/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.4987e-04 - learning_rate: 1.2500e-04
# Epoch 424/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.4974e-04 - learning_rate: 1.2500e-04
# Epoch 425/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.4963e-04 - learning_rate: 1.2500e-04
# Epoch 426/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4951e-04 - learning_rate: 1.2500e-04
# Epoch 427/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4938e-04 - learning_rate: 1.2500e-04
# Epoch 428/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.4926e-04 - learning_rate: 1.2500e-04
# Epoch 429/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.4915e-04 - learning_rate: 1.2500e-04
# Epoch 430/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.4903e-04 - learning_rate: 1.2500e-04
# Epoch 431/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.4892e-04 - learning_rate: 1.2500e-04
# Epoch 432/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4879e-04 - learning_rate: 1.2500e-04
# Epoch 433/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 1.4868e-04 - learning_rate: 1.2500e-04
# Epoch 434/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4856e-04 - learning_rate: 1.2500e-04
# Epoch 435/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.4844e-04 - learning_rate: 1.2500e-04
# Epoch 436/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4832e-04 - learning_rate: 1.2500e-04
# Epoch 437/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4818e-04 - learning_rate: 1.2500e-04
# Epoch 438/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.4807e-04 - learning_rate: 1.2500e-04
# Epoch 439/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 1.4794e-04 - learning_rate: 1.2500e-04
# Epoch 440/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4784e-04 - learning_rate: 1.2500e-04
# Epoch 441/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4771e-04 - learning_rate: 1.2500e-04
# Epoch 442/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.4759e-04 - learning_rate: 1.2500e-04
# Epoch 443/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4747e-04 - learning_rate: 1.2500e-04
# Epoch 444/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4735e-04 - learning_rate: 1.2500e-04
# Epoch 445/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4722e-04 - learning_rate: 1.2500e-04
# Epoch 446/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 1.4711e-04 - learning_rate: 1.2500e-04
# Epoch 447/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4698e-04 - learning_rate: 1.2500e-04
# Epoch 448/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4687e-04 - learning_rate: 1.2500e-04
# Epoch 449/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 1.4675e-04 - learning_rate: 1.2500e-04
# Epoch 450/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4663e-04 - learning_rate: 1.2500e-04
# Epoch 451/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.4651e-04 - learning_rate: 1.2500e-04
# Epoch 452/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4639e-04 - learning_rate: 1.2500e-04
# Epoch 453/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.4627e-04 - learning_rate: 1.2500e-04
# Epoch 454/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.4614e-04 - learning_rate: 1.2500e-04
# Epoch 455/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4602e-04 - learning_rate: 1.2500e-04
# Epoch 456/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.4590e-04 - learning_rate: 1.0000e-04
# Epoch 457/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.4580e-04 - learning_rate: 1.0000e-04
# Epoch 458/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 1.4569e-04 - learning_rate: 1.0000e-04
# Epoch 459/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.4561e-04 - learning_rate: 1.0000e-04
# Epoch 460/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4552e-04 - learning_rate: 1.0000e-04
# Epoch 461/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4541e-04 - learning_rate: 1.0000e-04
# Epoch 462/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.4531e-04 - learning_rate: 1.0000e-04
# Epoch 463/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.4521e-04 - learning_rate: 1.0000e-04
# Epoch 464/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.4512e-04 - learning_rate: 1.0000e-04
# Epoch 465/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.4503e-04 - learning_rate: 1.0000e-04
# Epoch 466/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.4493e-04 - learning_rate: 1.0000e-04
# Epoch 467/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4483e-04 - learning_rate: 1.0000e-04
# Epoch 468/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4473e-04 - learning_rate: 1.0000e-04
# Epoch 469/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.4464e-04 - learning_rate: 1.0000e-04
# Epoch 470/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4454e-04 - learning_rate: 1.0000e-04
# Epoch 471/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.4443e-04 - learning_rate: 1.0000e-04
# Epoch 472/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.4434e-04 - learning_rate: 1.0000e-04
# Epoch 473/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 1.4424e-04 - learning_rate: 1.0000e-04
# Epoch 474/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 1.4414e-04 - learning_rate: 1.0000e-04
# Epoch 475/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.4405e-04 - learning_rate: 1.0000e-04
# Epoch 476/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4394e-04 - learning_rate: 1.0000e-04
# Epoch 477/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4385e-04 - learning_rate: 1.0000e-04
# Epoch 478/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4375e-04 - learning_rate: 1.0000e-04
# Epoch 479/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4365e-04 - learning_rate: 1.0000e-04
# Epoch 480/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4355e-04 - learning_rate: 1.0000e-04
# Epoch 481/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.4346e-04 - learning_rate: 1.0000e-04
# Epoch 482/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 1.4335e-04 - learning_rate: 1.0000e-04
# Epoch 483/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4326e-04 - learning_rate: 1.0000e-04
# Epoch 484/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.4316e-04 - learning_rate: 1.0000e-04
# Epoch 485/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4306e-04 - learning_rate: 1.0000e-04
# Epoch 486/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.4296e-04 - learning_rate: 1.0000e-04
# Epoch 487/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.4286e-04 - learning_rate: 1.0000e-04
# Epoch 488/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 1.4277e-04 - learning_rate: 1.0000e-04
# Epoch 489/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.4266e-04 - learning_rate: 1.0000e-04
# Epoch 490/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 1.4257e-04 - learning_rate: 1.0000e-04
# Epoch 491/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4248e-04 - learning_rate: 1.0000e-04
# Epoch 492/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4236e-04 - learning_rate: 1.0000e-04
# Epoch 493/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 1.4227e-04 - learning_rate: 1.0000e-04
# Epoch 494/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 1.4218e-04 - learning_rate: 1.0000e-04
# Epoch 495/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.4206e-04 - learning_rate: 1.0000e-04
# Epoch 496/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 1.4197e-04 - learning_rate: 1.0000e-04
# Epoch 497/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.4187e-04 - learning_rate: 1.0000e-04
# Epoch 498/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 1.4177e-04 - learning_rate: 1.0000e-04
# Epoch 499/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.4168e-04 - learning_rate: 1.0000e-04
# Epoch 500/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4157e-04 - learning_rate: 1.0000e-04
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026154E74E50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/stepWARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026154E74E50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 0.825

# %%
import matplotlib.pyplot as plt

# you can retrieve the history of training to visualize the loss
loss = cnn_cls.history.history["loss"]
plt.plot(loss, color='blue')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Evolution of the training loss.")
plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

cnn_best = tf.keras.models.load_model("best_cnn.keras", compile=False)

# %%
#get conv weights of layer 1  
conv1_weights = cnn_best.layers[1].get_weights()[0]

#get conv weights of layer 2  
conv2_weights = cnn_best.layers[4].get_weights()[0]

fig,ax = plt.subplots(2,6,figsize=(20,7))

cmap = plt.get_cmap('tab20c')
values = np.linspace(0, 1, 18)
np.random.shuffle(values)

for i in range(6):
  ax[0,i].plot(conv1_weights[:,0,i],color=cmap(values[i]))
  ax[0,i].set_title('Conv layer 1, Filter ' + str(i+1))
  ax[1,i].plot(conv2_weights[:,0,i],color=cmap(values[6+i]))
  ax[1,i].set_title('Conv layer 2, Filter ' + str(i+1))
plt.tight_layout()
plt.show()

#os.remove("best_cnn.keras")

# %%
import tensorflow as tf
from aeon.regression.deep_learning import FCNRegressor
from sklearn.metrics import mean_squared_error

cnn_rgs = FCNRegressor(n_epochs=500)
cnn_rgs.fit(X_train_r, y_train_mtser)
cnn_rgs_preds = cnn_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, cnn_rgs_preds))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1.1462457110901818

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, cnn_rgs_preds, title="FCNRegressor Predictions")
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'FCNRegressor Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %%
import tensorflow as tf
from aeon.classification.deep_learning import  TimeCNNClassifier
from sklearn.metrics import accuracy_score

# n_epochs chooses the number of training iterations
# verbose show the network's detail and the logs of training
cnn_cls = TimeCNNClassifier(n_epochs=500, verbose=True, save_best_model=True, best_file_name="best_time_cnn")
cnn_cls.fit(X_train_c, y_train_mtsc)
cnn_cls_preds = cnn_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, cnn_cls_preds))
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 100, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 94, 6)          │           174 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d               │ (None, 31, 6)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 25, 12)         │           516 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d_1             │ (None, 8, 12)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 2)              │           194 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 884 (3.45 KB)
#  Trainable params: 884 (3.45 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5078 - loss: 0.2581
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5078 - loss: 0.2528
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5453 - loss: 0.2504
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4922 - loss: 0.2500
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4922 - loss: 0.2506
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4922 - loss: 0.2513
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4922 - loss: 0.2514
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4922 - loss: 0.2510
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4922 - loss: 0.2501
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4922 - loss: 0.2491
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4922 - loss: 0.2482
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4922 - loss: 0.2474
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5125 - loss: 0.2467
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4922 - loss: 0.2461
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4922 - loss: 0.2455
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4922 - loss: 0.2450
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4922 - loss: 0.2445
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4922 - loss: 0.2440
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4922 - loss: 0.2434
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4922 - loss: 0.2429
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4922 - loss: 0.2423
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4922 - loss: 0.2416
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4766 - loss: 0.2409
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4766 - loss: 0.2401
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4766 - loss: 0.2393
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5125 - loss: 0.2385
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5844 - loss: 0.2376
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6406 - loss: 0.2368
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6938 - loss: 0.2359
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7859 - loss: 0.2350
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7859 - loss: 0.2341
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7984 - loss: 0.2332
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7984 - loss: 0.2322
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7984 - loss: 0.2313
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7984 - loss: 0.2303
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7984 - loss: 0.2293
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7984 - loss: 0.2282
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7984 - loss: 0.2272
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7984 - loss: 0.2261
# Epoch 40/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8109 - loss: 0.2250
# Epoch 41/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8109 - loss: 0.2239
# Epoch 42/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8109 - loss: 0.2228
# Epoch 43/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8109 - loss: 0.2216
# Epoch 44/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8109 - loss: 0.2204
# Epoch 45/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8109 - loss: 0.2193
# Epoch 46/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8109 - loss: 0.2181
# Epoch 47/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8469 - loss: 0.2168
# Epoch 48/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8469 - loss: 0.2156
# Epoch 49/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8469 - loss: 0.2143
# Epoch 50/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8469 - loss: 0.2131
# Epoch 51/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8469 - loss: 0.2118
# Epoch 52/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8469 - loss: 0.2105
# Epoch 53/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8469 - loss: 0.2092
# Epoch 54/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8469 - loss: 0.2078
# Epoch 55/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8469 - loss: 0.2065
# Epoch 56/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8469 - loss: 0.2052
# Epoch 57/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8469 - loss: 0.2038
# Epoch 58/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8469 - loss: 0.2024
# Epoch 59/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8469 - loss: 0.2010
# Epoch 60/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8469 - loss: 0.1996
# Epoch 61/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8469 - loss: 0.1982
# Epoch 62/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8469 - loss: 0.1968
# Epoch 63/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8469 - loss: 0.1954
# Epoch 64/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8469 - loss: 0.1940
# Epoch 65/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8672 - loss: 0.1926
# Epoch 66/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1912
# Epoch 67/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1898
# Epoch 68/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1883
# Epoch 69/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8875 - loss: 0.1869
# Epoch 70/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1855
# Epoch 71/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1841
# Epoch 72/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1827
# Epoch 73/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1813
# Epoch 74/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1799
# Epoch 75/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1785
# Epoch 76/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1771
# Epoch 77/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1758
# Epoch 78/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1744
# Epoch 79/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1731
# Epoch 80/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1717
# Epoch 81/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1704
# Epoch 82/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1691
# Epoch 83/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1678
# Epoch 84/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8875 - loss: 0.1665
# Epoch 85/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8875 - loss: 0.1653
# Epoch 86/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1640
# Epoch 87/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1628
# Epoch 88/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1615
# Epoch 89/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1603
# Epoch 90/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1591
# Epoch 91/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1580
# Epoch 92/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1568
# Epoch 93/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1556
# Epoch 94/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1545
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1534
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1523
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1512
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1501
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1490
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1480
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1469
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1459
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1449
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1439
# Epoch 105/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1429
# Epoch 106/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8875 - loss: 0.1419
# Epoch 107/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1409
# Epoch 108/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1400
# Epoch 109/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8875 - loss: 0.1390
# Epoch 110/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1381
# Epoch 111/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1372
# Epoch 112/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1363
# Epoch 113/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1354
# Epoch 114/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1345
# Epoch 115/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1336
# Epoch 116/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1327
# Epoch 117/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1318
# Epoch 118/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.1310
# Epoch 119/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1301
# Epoch 120/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1292
# Epoch 121/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8516 - loss: 0.1284
# Epoch 122/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8516 - loss: 0.1276
# Epoch 123/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8516 - loss: 0.1267
# Epoch 124/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8516 - loss: 0.1259
# Epoch 125/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8516 - loss: 0.1251
# Epoch 126/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8516 - loss: 0.1243
# Epoch 127/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8516 - loss: 0.1235
# Epoch 128/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8516 - loss: 0.1227
# Epoch 129/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8516 - loss: 0.1219
# Epoch 130/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8516 - loss: 0.1211
# Epoch 131/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8516 - loss: 0.1203
# Epoch 132/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8516 - loss: 0.1195
# Epoch 133/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8516 - loss: 0.1187
# Epoch 134/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8516 - loss: 0.1180
# Epoch 135/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8516 - loss: 0.1172
# Epoch 136/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8516 - loss: 0.1164
# Epoch 137/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1157
# Epoch 138/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1149
# Epoch 139/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1141
# Epoch 140/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8719 - loss: 0.1134
# Epoch 141/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8719 - loss: 0.1126
# Epoch 142/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1119
# Epoch 143/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1111
# Epoch 144/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1103
# Epoch 145/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1096
# Epoch 146/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1088
# Epoch 147/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8719 - loss: 0.1081
# Epoch 148/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8719 - loss: 0.1074
# Epoch 149/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1066
# Epoch 150/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1059
# Epoch 151/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1051
# Epoch 152/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8719 - loss: 0.1044
# Epoch 153/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8719 - loss: 0.1037
# Epoch 154/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1029
# Epoch 155/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1022
# Epoch 156/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1015
# Epoch 157/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1007
# Epoch 158/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.1000
# Epoch 159/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0993
# Epoch 160/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8719 - loss: 0.0986
# Epoch 161/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0978
# Epoch 162/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8719 - loss: 0.0971
# Epoch 163/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0964
# Epoch 164/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0957
# Epoch 165/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0950
# Epoch 166/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0943
# Epoch 167/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0935
# Epoch 168/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0928
# Epoch 169/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0921
# Epoch 170/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0914
# Epoch 171/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.0907
# Epoch 172/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0900
# Epoch 173/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8922 - loss: 0.0893
# Epoch 174/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0887
# Epoch 175/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0880
# Epoch 176/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0873
# Epoch 177/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0866
# Epoch 178/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0859
# Epoch 179/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8922 - loss: 0.0853
# Epoch 180/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0846
# Epoch 181/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8922 - loss: 0.0839
# Epoch 182/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0833
# Epoch 183/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8922 - loss: 0.0826
# Epoch 184/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8922 - loss: 0.0819
# Epoch 185/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0813
# Epoch 186/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0806
# Epoch 187/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8922 - loss: 0.0800
# Epoch 188/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0794
# Epoch 189/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0787
# Epoch 190/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0781
# Epoch 191/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0774
# Epoch 192/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0768
# Epoch 193/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0762
# Epoch 194/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0756
# Epoch 195/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8922 - loss: 0.0749
# Epoch 196/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9281 - loss: 0.0743
# Epoch 197/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9281 - loss: 0.0737
# Epoch 198/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9281 - loss: 0.0731
# Epoch 199/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9281 - loss: 0.0725
# Epoch 200/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9281 - loss: 0.0719
# Epoch 201/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9281 - loss: 0.0713
# Epoch 202/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9281 - loss: 0.0707
# Epoch 203/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9281 - loss: 0.0701
# Epoch 204/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9281 - loss: 0.0695
# Epoch 205/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9281 - loss: 0.0689
# Epoch 206/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9281 - loss: 0.0683
# Epoch 207/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9281 - loss: 0.0677
# Epoch 208/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0671
# Epoch 209/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0666
# Epoch 210/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0660
# Epoch 211/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0654
# Epoch 212/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0649
# Epoch 213/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0643
# Epoch 214/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0637
# Epoch 215/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0632
# Epoch 216/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0626
# Epoch 217/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0621
# Epoch 218/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0615
# Epoch 219/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0610
# Epoch 220/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9641 - loss: 0.0604
# Epoch 221/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0599
# Epoch 222/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9641 - loss: 0.0594
# Epoch 223/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0588
# Epoch 224/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0583
# Epoch 225/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9641 - loss: 0.0578
# Epoch 226/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0573
# Epoch 227/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0568
# Epoch 228/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0562
# Epoch 229/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0557
# Epoch 230/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0552
# Epoch 231/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0547
# Epoch 232/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0543
# Epoch 233/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0538
# Epoch 234/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0533
# Epoch 235/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0528
# Epoch 236/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.0523
# Epoch 237/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9641 - loss: 0.0519
# Epoch 238/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0514
# Epoch 239/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0509
# Epoch 240/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0505
# Epoch 241/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0500
# Epoch 242/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0496
# Epoch 243/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0491
# Epoch 244/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0487
# Epoch 245/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0483
# Epoch 246/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0478
# Epoch 247/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0474
# Epoch 248/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0470
# Epoch 249/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0466
# Epoch 250/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0462
# Epoch 251/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0458
# Epoch 252/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0454
# Epoch 253/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0450
# Epoch 254/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0446
# Epoch 255/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0442
# Epoch 256/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0438
# Epoch 257/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0434
# Epoch 258/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0430
# Epoch 259/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0426
# Epoch 260/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0423
# Epoch 261/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0419
# Epoch 262/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0415
# Epoch 263/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0412
# Epoch 264/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0408
# Epoch 265/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0404
# Epoch 266/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0401
# Epoch 267/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0397
# Epoch 268/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0394
# Epoch 269/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0390
# Epoch 270/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0387
# Epoch 271/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0384
# Epoch 272/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0380
# Epoch 273/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0377
# Epoch 274/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0374
# Epoch 275/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0370
# Epoch 276/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0367
# Epoch 277/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0364
# Epoch 278/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0361
# Epoch 279/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0358
# Epoch 280/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0355
# Epoch 281/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0352
# Epoch 282/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0348
# Epoch 283/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0345
# Epoch 284/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0342
# Epoch 285/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0340
# Epoch 286/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0337
# Epoch 287/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0334
# Epoch 288/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0331
# Epoch 289/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0328
# Epoch 290/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0325
# Epoch 291/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0322
# Epoch 292/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0320
# Epoch 293/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0317
# Epoch 294/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0314
# Epoch 295/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0311
# Epoch 296/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0309
# Epoch 297/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0306
# Epoch 298/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0304
# Epoch 299/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0301
# Epoch 300/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 301/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0296
# Epoch 302/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0293
# Epoch 303/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0291
# Epoch 304/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 305/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0286
# Epoch 306/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0283
# Epoch 307/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0281
# Epoch 308/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0279
# Epoch 309/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0276
# Epoch 310/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0274
# Epoch 311/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0272
# Epoch 312/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0269
# Epoch 313/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0267
# Epoch 314/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0265
# Epoch 315/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0263
# Epoch 316/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0260
# Epoch 317/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0258
# Epoch 318/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0256
# Epoch 319/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0254
# Epoch 320/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0252
# Epoch 321/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 322/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0248
# Epoch 323/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0246
# Epoch 324/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 325/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0242
# Epoch 326/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0240
# Epoch 327/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0238
# Epoch 328/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0236
# Epoch 329/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0234
# Epoch 330/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0232
# Epoch 331/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0230
# Epoch 332/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0228
# Epoch 333/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0226
# Epoch 334/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0224
# Epoch 335/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0223
# Epoch 336/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0221
# Epoch 337/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0219
# Epoch 338/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0217
# Epoch 339/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0215
# Epoch 340/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0214
# Epoch 341/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0212
# Epoch 342/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0210
# Epoch 343/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0209
# Epoch 344/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0207
# Epoch 345/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0205
# Epoch 346/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0204
# Epoch 347/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0202
# Epoch 348/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0200
# Epoch 349/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0199
# Epoch 350/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 351/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0196
# Epoch 352/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0194
# Epoch 353/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0193
# Epoch 354/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0191
# Epoch 355/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0190
# Epoch 356/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0188
# Epoch 357/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0187
# Epoch 358/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 359/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0184
# Epoch 360/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0182
# Epoch 361/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0181
# Epoch 362/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 363/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0178
# Epoch 364/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0177
# Epoch 365/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0175
# Epoch 366/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0174
# Epoch 367/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0173
# Epoch 368/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0171
# Epoch 369/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0170
# Epoch 370/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0169
# Epoch 371/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0167
# Epoch 372/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 373/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0165
# Epoch 374/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0164
# Epoch 375/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0162
# Epoch 376/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 377/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0160
# Epoch 378/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0159
# Epoch 379/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0157
# Epoch 380/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0156
# Epoch 381/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0155
# Epoch 382/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0154
# Epoch 383/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0153
# Epoch 384/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0152
# Epoch 385/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0150
# Epoch 386/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0149
# Epoch 387/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0148
# Epoch 388/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 389/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0146
# Epoch 390/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0145
# Epoch 391/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 392/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 393/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 394/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 395/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 396/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 397/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 398/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 399/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 400/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 401/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 402/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 403/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 404/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 405/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 406/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 407/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 408/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 409/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 410/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 411/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 412/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 413/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 414/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 415/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 416/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 417/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 418/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 419/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 420/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 421/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 422/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 423/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 424/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 425/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0113
# Epoch 426/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 427/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 428/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 429/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 430/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0109
# Epoch 431/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 432/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 433/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 434/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 435/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 436/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 437/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 438/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 439/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 440/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 441/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 442/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 443/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 444/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 445/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 446/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 447/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 448/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 449/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 450/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 451/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 452/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 453/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 454/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 455/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 456/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 457/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 458/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 459/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 460/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 461/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 462/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 463/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 464/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 465/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 466/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 467/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 468/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 469/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 470/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 471/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 472/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 473/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 474/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 475/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 476/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 477/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 478/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 479/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 480/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 481/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 482/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 483/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 484/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 485/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 486/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 487/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 488/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 489/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 490/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 491/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 492/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 493/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 494/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 495/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 496/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 497/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 498/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 499/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 500/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0070
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 0.625

# %%
import tensorflow as tf
cnn_t_best = tf.keras.models.load_model("best_time_cnn.keras", compile=False)
cnn_t_best.layers
# Out:
# [<InputLayer name=input_layer_4, built=True>,
#  <Conv1D name=conv1d_6, built=True>,
#  <AveragePooling1D name=average_pooling1d, built=True>,
#  <Conv1D name=conv1d_7, built=True>,
#  <AveragePooling1D name=average_pooling1d_1, built=True>,
#  <Flatten name=flatten_2, built=True>,
#  <Dense name=dense_10, built=True>]

# %%
#get conv weights of layer 1  
conv1_weights = cnn_t_best.layers[1].get_weights()[0]

#get conv weights of layer 2  
conv2_weights = cnn_t_best.layers[3].get_weights()[0]

fig,ax = plt.subplots(2,6,figsize=(20,7))

cmap = plt.get_cmap('tab20c')
values = np.linspace(0, 1, 18)
np.random.shuffle(values)

for i in range(6):
  ax[0,i].plot(conv1_weights[:,0,i],color=cmap(values[i]))
  ax[0,i].set_title('Conv layer 1, Filter ' + str(i+1))
  ax[1,i].plot(conv2_weights[:,0,i],color=cmap(values[6+i]))
  ax[1,i].set_title('Conv layer 2, Filter ' + str(i+1))
plt.tight_layout()
plt.show()

#os.remove("best_cnn.keras")

# %%
import tensorflow as tf
from aeon.regression.deep_learning import  TimeCNNRegressor
from aeon.visualisation import plot_scatter_predictions
from sklearn.metrics import mean_squared_error

cnn_rgs = TimeCNNRegressor(n_epochs=500)
cnn_rgs.fit(X_train_r, y_train_mtser)
cnn_rgs_preds = cnn_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, cnn_rgs_preds))

plot_scatter_predictions(y_test_mtser, cnn_rgs_preds, title="TimeCNNRegressor Predictions")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1.4492177425331283
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'TimeCNNRegressor Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# # Упражнения <a id='tasks'></a>
#
# 1. Взять выбранные для лабы 9 набор(ы) данных. Можно взять разные наборы для классификации/регрессии (но причину надо будет обосновать)
#
# 2. Отрисовать данные
#
# 3. Попробовать все методы классификации и регрессии, описанные в блоноте:
#     Distance-based
#     Свертки (модели семейства Rocket и Hydra)
#     Feature-based
#     Deep Learning
#
#     Для каждого подхода обучть не менее 3х разных моделей для классификации и регрессии.

# %%
from aeon.datasets import load_classification
from sklearn.preprocessing import LabelEncoder

X_train, y_train = load_classification("ArrowHead", split="TRAIN")
X_test, y_test = load_classification("ArrowHead", split="TEST")

le = LabelEncoder()
y_train_r = le.fit_transform(y_train).astype(float)
y_test_r = le.transform(y_test).astype(float)

X_train_c = (X_train - X_train.mean(axis=-1, keepdims=True)) / (X_train.std(axis=-1, keepdims=True) + 1e-8)
X_test_c = (X_test - X_test.mean(axis=-1, keepdims=True)) / (X_test.std(axis=-1, keepdims=True) + 1e-8)
X_train_r = X_train_c
X_test_r = X_test_c

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
print("Classes:", np.unique(y_train))
print("Series length:", X_train.shape[2])
# Out:
# Train shape: (36, 1, 251)
# Test shape: (175, 1, 251)
# Classes: ['0' '1' '2']
# Series length: 251

# %%
classes = np.unique(y_train)
n_examples = 3

fig, ax = plt.subplots(len(classes), n_examples, figsize=(12, 6))
if len(classes) == 1:
    ax = np.array([ax])

for i, cls in enumerate(classes):
    idx = np.where(y_train == cls)[0][:n_examples]
    for j, id_ in enumerate(idx):
        ax[i][j].plot(X_train[id_][0])
        ax[i][j].set_title(f"Class {cls}")
        ax[i][j].set_xlabel("Time")
        ax[i][j].set_ylabel("Value")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, mean_squared_error
import tensorflow as tf
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier, ElasticEnsemble, ProximityForest
from aeon.regression.distance_based import KNeighborsTimeSeriesRegressor
from aeon.classification.convolution_based import RocketClassifier, MiniRocketClassifier, HydraClassifier
from aeon.regression.convolution_based import RocketRegressor, MiniRocketRegressor, HydraRegressor
from aeon.classification.feature_based import Catch22Classifier, SummaryClassifier
from aeon.regression.feature_based import Catch22Regressor, SummaryRegressor
from aeon.classification.deep_learning import MLPClassifier, FCNClassifier, TimeCNNClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from aeon.regression.deep_learning import MLPRegressor, FCNRegressor, TimeCNNRegressor

classification_models = {
    "distance KNN": KNeighborsTimeSeriesClassifier(n_neighbors=1, distance="dtw"),
    "distance ElasticEnsemble": ElasticEnsemble(distance_measures=["dtw", "erp", "msm"], proportion_of_param_options=0.2, n_jobs=-1, random_state=42),
    "distance ProximityForest": ProximityForest(n_trees=3, n_splitters=3, random_state=42, n_jobs=-1),
    "convolution Rocket": RocketClassifier(n_kernels=200, n_jobs=-1, random_state=42),
    "convolution MiniRocket": MiniRocketClassifier(n_kernels=200, n_jobs=-1, random_state=42),
    "convolution Hydra": HydraClassifier(n_groups=8, n_jobs=-1, random_state=42),
    "feature Catch22": Catch22Classifier(n_jobs=-1, random_state=42),
    "feature Summary": SummaryClassifier(n_jobs=-1, random_state=42),
    "feature Catch22 RF": Catch22Classifier(estimator=RandomForestClassifier(n_estimators=10, random_state=42), n_jobs=-1, random_state=42),
    "deep MLP": MLPClassifier(n_epochs=5, n_units=64, batch_size=16, random_state=42),
    "deep FCN": FCNClassifier(n_epochs=5, batch_size=16, random_state=42),
    "deep TimeCNN": TimeCNNClassifier(n_epochs=5, batch_size=16, random_state=42),
}

regression_models = {
    "distance KNN dtw": KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="dtw"),
    "distance KNN euclidean": KNeighborsTimeSeriesRegressor(n_neighbors=3, distance="euclidean"),
    "distance KNN msm": KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="msm"),
    "convolution Rocket": RocketRegressor(n_kernels=200, n_jobs=-1, random_state=42),
    "convolution MiniRocket": MiniRocketRegressor(n_kernels=200, n_jobs=-1, random_state=42),
    "convolution Hydra": HydraRegressor(n_groups=8, n_jobs=-1, random_state=42),
    "feature Catch22": Catch22Regressor(n_jobs=-1, random_state=42),
    "feature Summary": SummaryRegressor(n_jobs=-1, random_state=42),
    "feature Catch22 RF": Catch22Regressor(estimator=RandomForestRegressor(n_estimators=10, random_state=42), n_jobs=-1, random_state=42),
    "deep MLP": MLPRegressor(n_epochs=5, n_units=64, batch_size=16, random_state=42),
    "deep FCN": FCNRegressor(n_epochs=5, batch_size=16, random_state=42),
    "deep TimeCNN": TimeCNNRegressor(n_epochs=5, batch_size=16, random_state=42),
}

classification_results = {}
for name, model in classification_models.items():
    model.fit(X_train_c, y_train)
    preds = model.predict(X_test_c)
    classification_results[name] = accuracy_score(y_test, preds)
    print(name, classification_results[name])

regression_results = {}
for name, model in regression_models.items():
    model.fit(X_train_r, y_train_r)
    preds = model.predict(X_test_r)
    regression_results[name] = mean_squared_error(y_test_r, preds)
    print(name, regression_results[name])
# Out:
# distance KNN 0.7028571428571428
# distance ElasticEnsemble 0.8057142857142857
# distance ProximityForest 0.8228571428571428
# convolution Rocket 0.76
# convolution MiniRocket 0.7257142857142858
# convolution Hydra 0.8457142857142858
# feature Catch22 0.7542857142857143
# feature Summary 0.6457142857142857
# feature Catch22 RF 0.6628571428571428
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# deep MLP 0.3028571428571429
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# deep FCN 0.3028571428571429
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# deep TimeCNN 0.3942857142857143
# distance KNN dtw 0.4857142857142857
# distance KNN euclidean 0.3352380952380953
# distance KNN msm 0.36
# convolution Rocket 0.5832655112562163
# convolution MiniRocket 0.4145459127336663
# convolution Hydra 0.3462409726048984
# feature Catch22 0.37359728571428574
# feature Summary 0.34852385714285716
# feature Catch22 RF 0.4962857142857143
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# deep MLP 1.016810768345701
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# deep FCN 0.9254719777105349
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# deep TimeCNN 0.7115312661099739
